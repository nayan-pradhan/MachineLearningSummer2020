# %%
import os
import nltk
# Need to download nltk first
# nltk.download()
import nltk.corpus

# %%
import urllib.request
response =  urllib.request.urlopen('https://en.wikipedia.org/wiki/SpaceX')
html = response.read()
print(html)
# Out:
# b'\n\n\n<!DOCTYPE html>\n<html class="">\n<head>\n        <title>MarketWatch: Stock Market News - Financial News - MarketWatch</title>\n        <meta charset="utf-8">\n        <meta http-equiv="X-UA-Compatible" content="IE=edge">\n        <meta name="viewport" content="user-scalable=no, initial-scale=1.0, maximum-scale=1.0, width=device-width">\n            <meta name="robots" content="noarchive, noodp">\n<link rel="dns-prefetch" href="//sts.wsj.net" />\n<link rel="dns-prefetch" href="//s.marketwatch.com" />\n<link rel="dns-prefetch" href="//video-api.wsj.com" />\n<link rel="dns-prefetch" href="//fonts.wsj.net" />\n<link rel="dns-prefetch" href="//m.wsj.net" />\n<link rel="dns-prefetch" href="//mwstream.wsj.net" />\n<link rel="dns-prefetch" href="//tags.tiqcdn.com" />\n<link rel="dns-prefetch" href="//s.ntv.io" />\n<link rel="dns-prefetch" href="//cdn.cxense.com" />\n<link rel="dns-prefetch" href="//a248.e.akamai.net" />\n<link rel="dns-prefetch" href="//om.dowjoneson.com" />\n<link rel="dns-prefetch" href="//bam.nr-data.net" />\n<link rel="dns-prefetch" href="//www.googletagservices.com" />\n<link rel="dns-prefetch" href="//partner.googleadservices.com" />\n<link rel="dns-prefetch" href="//pagead2.googlesyndication.com" />\n<link rel="dns-prefetch" href="//pubads.g.doubleclick.net" />\n<link rel="dns-prefetch" href="//tpc.googlesyndication.com" />\n<link rel="dns-prefetch" href="//tealium.hs.llnwd.net"/>\n<link rel="dns-prefetch" href="//contextual.media.net" />\n<link rel="dns-prefetch" href="//js-agent.newrelic.com" /><link href="https://mw4.wsj.net/mw5/content/images/favicons/apple-touch-icon.png" rel="apple-touch-icon" />\r\n<link href="https://mw4.wsj.net/mw5/content/images/favicons/apple-touch-icon-152x152.png" rel="apple-touch-icon" sizes="152x152" />\r\n<link href="https://mw4.wsj.net/mw5/content/images/favicons/apple-touch-icon-167x167.png" rel="apple-touch-icon" sizes="167x167" />\r\n<link href="https://mw4.wsj.net/mw5/content/images/favicons/apple-touch-icon-180x180.png" rel="apple-touch-icon" sizes="180x180" />\r\n<link href="https://mw4.wsj.net/mw5/content/logos/favicon.ico" rel="shortcut icon" />        <meta name="apple-itunes-app" content="app-id=336693422">\n        <meta name="fb:app_id" content="283204329838">\n        <meta property="fb:pages" content="131043201847" />\n        <meta property="og:site_name" content="MarketWatch">\n        <meta name="twitter:site:id" content="624413">\n        <meta name="twitter:domain" content="marketwatch.com">\n        <meta name="twitter:image:width" content="1200">\n        <meta name="twitter:image:height" content="630">\n        <meta name="twitter:card" content="summary_large_image">\n        <meta name="twitter:creator" content="@marketwatch">\n        <meta name="referrer" content="no-referrer-when-downgrade">\n        <meta name="article:publisher" content="https://www.facebook.com/marketwatch">\n        <meta name="theme-color" content="#2e2e2f" />\n        <meta name="chartjs" content="https://sts3.wsj.net/bucket-a/maggie/static/js/chart-eb34acf0ea.min.js">\n\n\r\n\r\n\r\n<meta name="description" content="MarketWatch provides the latest stock market, financial and business news. Get stock market quotes, personal finance advice, company news and more." />\r\n<meta property="og:title" content="Home Page - MarketWatch">\r\n<meta property="og:url" content="https://www.marketwatch.com/">\r\n<meta property="og:image" content="https://mw3.wsj.net/mw5/content/logos/mw_logo_social.png">\r\n<meta name="twitter:description" content="MarketWatch provides the latest stock market, financial and business news. Get stock market quotes, personal finance advice, company news and more.">\r\n<meta name="twitter:image" content="https://mw3.wsj.net/mw5/content/logos/mw_logo_social.png">\r\n<meta name="parsely-title" content="Home Page - MarketWatch">\r\n<meta name="parsely-link" content="https://www.marketwatch.com/">\r\n<meta name="parsely-type" content="post">\r\n<meta name="par ...

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(html,'html5lib')
text = soup.get_text(strip = True)
print(text)
# Out:
# MarketWatch: Stock Market News - Financial News - MarketWatch@import url("https://fonts.googleapis.com/css?family=Lato:700&text=amp1234567890.%25%24%E2%82%AC%C2%A3%C2%A5%C2%A2");[class*=" icon--"]:before,[class^=icon--]:before{font-family:icons!important;speak:none;font-style:normal;font-weight:400;font-variant:normal;text-transform:none;line-height:1;min-width:18px;display:inline-block;content:"";-webkit-font-smoothing:antialiased;-moz-osx-font-smoothing:grayscale}.slide-down{-webkit-animation-name:a;animation-name:a;-webkit-animation-duration:.5s;animation-duration:.5s;-webkit-animation-timing-function:ease;animation-timing-function:ease;visibility:visible!important}@-webkit-keyframes a{0%{-webkit-transform:translateY(-100%);transform:translateY(-100%)}to{-webkit-transform:translateY(0);transform:translateY(0)}}@keyframes a{0%{-webkit-transform:translateY(-100%);transform:translateY(-100%)}to{-webkit-transform:translateY(0);transform:translateY(0)}}@-webkit-keyframes b{0%{opacity:0}50%{opacity:1}to{opacity:0}}@keyframes b{0%{opacity:0}50%{opacity:1}to{opacity:0}}.font--smallest{font-size:.64286rem}.font--smaller{font-size:.71429rem}.font--small{font-size:.85714rem}.font--bold{font-weight:700}a,abbr,acronym,address,applet,article,aside,audio,b,big,blockquote,body,canvas,caption,center,cite,code,dd,del,details,dfn,div,dl,dt,em,embed,fieldset,figcaption,figure,footer,form,h1,h2,h3,h4,h5,h6,header,hgroup,html,i,iframe,img,ins,kbd,label,legend,li,mark,menu,nav,object,ol,output,p,pre,q,ruby,s,samp,section,small,span,strike,strong,sub,summary,sup,table,tbody,td,tfoot,th,thead,time,tr,tt,u,ul,var,video{margin:0;padding:0;border:0;font-size:100%;font:inherit;vertical-align:baseline}article,aside,details,figcaption,figure,footer,header,hgroup,menu,nav,section{display:block}body{line-height:1.375}ol,ul{list-style:none}blockquote,q{quotes:none}blockquote:after,blockquote:before,q:after,q:before{content:"";content:none}table{border-collapse:collapse;border-spacing:0}body,html{margin:0;overflow-x:hidden;padding:0}html{box-sizing:border-box;font-size:14px;line-height:1.375;-webkit-backface-visibility:hidden;backface-visibility:hidden}*,:after,:before{box-sizing:inherit;-webkit-tap-highlight-color:rgba(0,0,0,0)}body{margin:0;font-family:Lato,sans-serif;font-size:1rem;color:#202020}body>iframe{display:none}h1,h2,h3,h4,h5,h6{margin:0;font-weight:700}a{color:inherit;text-decoration:none}em{font-style:italic}strong{font-weight:700}button:hover,select:hover{cursor:pointer}button,input,select{border:none;border-radius:0;background:none;-webkit-appearance:none;-moz-appearance:none;appearance:none}button:focus,input:focus,select:focus{outline:none}option{background:#fff;color:#202020}img{display:block;width:100%}ul{list-style-type:none}li,ul{margin:0;padding:0}sub,sup{font-size:75%;line-height:0;position:relative;vertical-align:baseline}sup{top:-.5em}sub{bottom:-.25em}body:after,template{display:none}body:after{content:"ExtraLarge"}@media (max-width:1295px){body:after{content:"Large"}}@media (max-width:975px){body:after{content:"Medium"}}@media (max-width:655px){body:after{content:"Small"}}body{padding-top:50px}body.has-bulletin{padding-top:90px}body.has-bulletins{padding-top:130px}.container{display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-flow:row wrap;-ms-flex-flow:row wrap;flex-flow:row wrap;-webkit-align-items:flex-start;-ms-flex-align:start;align-items:flex-start;margin:0 auto;max-width:1280px;width:100%}.container .region--primary{max-width:960px}.container .region--aside{max-width:320px;-webkit-align-self:stretch;-ms-flex-item-align:stretch;-ms-grid-row-align:stretch;align-self:stretch}.region{-webkit-align-content:flex-start;-ms-flex-line-pack:start;align-content:flex-start}.component,.region{position:relative;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-flow:row wrap;-ms-flex-flow:row wrap;flex-flow:row wrap;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;wi ...
# /*! onloadCSS. (onload callback for loadCSS) [c]2017 Filament Group, Inc. MIT License */
# /* global navigator */
# /* exported onloadCSS */
# function onloadCSS(e,t){function n(){!a&&t&&(a=!0,t.call(e))}var a;e.addEventListener&&e.addEventListener("load",n),e.attachEvent&&e.attachEvent("onload",n),"isApplicationInstalled"in navigator&&"onloadcssdefined"in e&&e.onloadcssdefined(n)}if(document.createElement("picture"),window.lazySizesConfig=window.lazySizesConfig||{},lazySizesConfig.loadMode=1,lazySizesConfig.throttle=600,window.addEventListener("load",function(){lazySizesConfig.throttle=150}),/*! EnhanceJS: a progressive enhancement boilerplate. Copyright 2014 @scottjehl, Filament Group, Inc. Licensed MIT */
# function(e,t){"use strict";function n(t,n){var a=e.document.getElementsByTagName("script")[0],o=e.document.createElement("script");return o.src=t,o.async=!0,n&&o.addEventListener("load",n),a.parentNode.insertBefore(o,a),o}function a(t){for(var n,a=e.document.getElementsByTagName("meta"),o=0;o<a.length;o++)if(a[o].name&&a[o].name===t){n=a[o];break}return n}function o(n,a,o){var r;if(a===t){var i="; "+e.document.cookie,l=i.split("; "+n+"=");return 2==l.length?l.pop().split(";").shift():null}if(a===!1&&(o=-1),o){var d=new Date;d.setTime(d.getTime()+24*o*60*60*1e3),r="; expires="+d.toGMTString()}else r="";e.document.cookie=n+"="+a+r+"; path=/; domain=.marketwatch.com"}function r(e){e.rel="stylesheet";var t=e.dataset.cookie,n=e.dataset.key;t&&n&&o(t,n,7)}var i=e.setTimeout,l={},d=e.document,s=d.documentElement,c=(d.head||d.getElementsByTagName("head")[0],["enhanced"]);l.loadJS=n;var u=function(t,n,a){function o(e){return d.body?e():void i(function(){o(e)})}function r(){s.addEventListener&&s.removeEventListener("load",r),s.media=a||"all"}var l,d=e.document,s=d.createElement("link");if(n)l=n;else{var c=(d.body||d.getElementsByTagName("head")[0]).childNodes;l=c[c.length-1]}var u=d.styleSheets;s.rel="stylesheet",s.href=t,s.media="only x",o(function(){l.parentNode.insertBefore(s,n?l:l.nextSibling)});var f=function(e){for(var t=s.href,n=u.length;n--;)if(u[n].href===t)return e();i(function(){f(e)})};return s.addEventListener&&s.addEventListener("load",r),s.onloadcssdefined=f,f(r),s};"undefined"!=typeof exports?exports.loadCSS=u:e.loadCSS=u,l.loadCSS=u,l.getMeta=a,l.cookie=o,e.loadedCss=r,l.loadedCss=r,"querySelector"in d&&(s.className+=" "+c.join(" "),e.enhance=l)}(this),/*! loadCSS rel=preload polyfill. [c]2017 Filament Group, Inc. MIT License */
# function(e){if(e.loadCSS){var t=loadCSS.relpreload={};t.support=function(){try{return e.document.createElement("link").relList.supports("preload")}catch(t){return!1}};var n=function(e){return function(){loadedCss(e)}};if(t.poly=function(){for(var t=e.document.getElementsByTagName("link"),a=0;a<t.length;a++){var o=t[a];if("preload"===o.rel&&"style"===o.getAttribute("as")){var r=e.loadCSS(o.href,o,o.getAttribute("media"));o.rel=null,o.setAttribute("onload",null),onloadCSS&&loadedCss&&onloadCSS(r,n(o))}}},!t.support()){t.poly();var a=e.setInterval(t.poly,300);e.addEventListener&&e.addEventListener("load",function(){t.poly(),e.clearInterval(a)}),e.attachEvent&&e.attachEvent("onload",function(){e.clearInterval(a)})}}}(this),"undefined"==typeof MarketWatch)var MarketWatch={};!function(){function e(){try{var e=window.localStorage,t="__storage_test__";return e.setItem(t,t),e.removeItem(t),!0}catch(n){return!1}}var t;MarketWatch.isStorageAvailable=function(){return"undefined"!=typeof t?t:t=e()}}();window.NREUM||(NREUM={}),__nr_require=function(t,e,n){function r(n){if(!e[n]){var o=e[n]={exports:{}};t[n][0].call(o.exports,function(e){var o=t[n][1][e];return r(o||e)},o,o.exports)}return e[n].exports}if("function"==typeof __nr_require)return __nr_require;for(var o=0;o<n.length;o++)r(n[o]);return r}({1:[function(t,e,n){function r(t){try{s.console&&console.log(t)}catch(e){}}var o,i=t("ee"),a=t(23),s={};try{o=localStorage.getItem("__nr_flags").split(","),console&&"function"==typeof console.log&&(s.console=!0,o.indexOf("dev")!==-1&&(s.dev=!0),o.indexOf("nr_dev")!==-1&&(s.nrDev=!0))}catch(c){}s.nrDev&&i.on("internal-error",function(t){r(t.stack)}),s.dev&&i.on("fn-err",function(t,e,n){r(n.stack)}),s.dev&&(r("NR AGENT IN DEVELOPMENT MODE"),r("flags: "+a(s,function(t,e){return t}).join(", ")))},{}],2:[function(t,e,n){function r(t,e,n,r,s){try{p?p-=1:o(s||new UncaughtException(t,e,n),!0)}catch(f){try{i("ierr",[f,c.now(),!0])}catch(d){}}return"function"==typeof u&&u.apply(this,a(arguments))}function UncaughtException(t,e,n){this.message=t||"Uncaught error with no additional information",this.sourceURL=e,this.line=n}function o(t,e){var n=e?null:c.now();i("err",[t,n])}var i=t("handle"),a=t(24),s=t("ee"),c=t("loader"),f=t("gos"),u=window.onerror,d=!1,l="nr@seenError",p=0;c.features.err=!0,t(1),window.onerror=r;try{throw new Error}catch(h){"stack"in h&&(t(13),t(12),"addEventListener"in window&&t(6),c.xhrWrappable&&t(14),d=!0)}s.on("fn-start",function(t,e,n){d&&(p+=1)}),s.on("fn-err",function(t,e,n){d&&!n[l]&&(f(n,l,function(){return!0}),this.thrown=!0,o(n))}),s.on("fn-end",function(){d&&!this.thrown&&p>0&&(p-=1)}),s.on("internal-error",function(t){i("ierr",[t,c.now(),!0])})},{}],3:[function(t,e,n){t("loader").features.ins=!0},{}],4:[function(t,e,n){function r(){M++,j=y.hash,this[u]=x.now()}function o(){M--,y.hash!==j&&i(0,!0);var t=x.now();this[h]=~~this[h]+t-this[u],this[d]=t}function i(t,e){E.emit("newURL",[""+y,e])}function a(t,e){t.on(e,function(){this[e]=x.now()})}var s="-start",c="-end",f="-body",u="fn"+s,d="fn"+c,l="cb"+s,p="cb"+c,h="jsTime",m="fetch",v="addEventListener",w=window,y=w.location,x=t("loader");if(w[v]&&x.xhrWrappable){var g=t(10),b=t(11),E=t(8),R=t(6),O=t(13),C=t(7),P=t(14),T=t(9),L=t("ee"),S=L.get("tracer");t(16),x.features.spa=!0;var j,M=0;L.on(u,r),L.on(l,r),L.on(d,o),L.on(p,o),L.buffer([u,d,"xhr-done","xhr-resolved"]),R.buffer([u]),O.buffer(["setTimeout"+c,"clearTimeout"+s,u]),P.buffer([u,"new-xhr","send-xhr"+s]),C.buffer([m+s,m+"-done",m+f+s,m+f+c]),E.buffer(["newURL"]),g.buffer([u]),b.buffer(["propagate",l,p,"executor-err","resolve"+s]),S.buffer([u,"no-"+u]),T.buffer(["new-jsonp","cb-start","jsonp-error","jsonp-end"]),a(P,"send-xhr"+s),a(L,"xhr-resolved"),a(L,"xhr-done"),a(C,m+s),a(C,m+"-done"),a(T,"new-jsonp"),a(T,"jsonp-end"),a(T,"cb-start"),E.on("pushState-end",i),E.on("replaceState-end",i),w[v]("hashchange",i,!0),w[v]("load",i,!0),w[v]("popstate",function(){i(0,M>1)},!0)}},{}],5:[function(t,e,n){function r(t){}if(window.pe ...
# ;NREUM.info={beacon:"bam.nr-data.net",errorBeacon:"bam.nr-data.net",licenseKey:"",applicationID:"206880789",sa:1}if ("PerformanceTiming" && "PerformanceObserver" in window) {
#             const observer = new PerformanceObserver(function(list) {
#                 for (const entry of list.getEntries()) {
#                     const metricName = entry.name;
#                     const time = Math.round(entry.startTime + entry.duration);
#                     if (typeof newrelic !== 'undefined') {
#                         newrelic.setCustomAttribute(metricName, time);
#                     }
#                 }
#             });
#             if ("PerformancePaintTiming" in window){observer.observe({entryTypes: ['paint', 'mark', 'measure']});}
#             else {observer.observe({entryTypes: ['mark', 'measure']});}
#         }window.googletag = window.googletag || { cmd: [] };
#         window.pbjs = window.pbjs || { que: [] };window.__mwads = window.__mwads || {};
#         window.__mwads.slots = {};
#         window.__mwads.gptEnabled = true;
#         window.__mwads.prebidEnabled = true;
#         window.__mwads.moatEnabled = true;
#         window.__mwads.breakpoints = { 'Small': 'at4units', 'Medium': 'at8units', 'Large': 'at12units', 'ExtraLarge': 'at16units' };
#         window.__mwads.mpuId = 'ad-display-ad';
#             window.__mwads.curatedMap = { A: 1088448, B: 1088449, C: 1091804, D: 1091805 };
#
#             window.__mwads.log = function() { }; // no-op
#
#         (function() {
#             googletag.cmd.push(function() {
#                 googletag.pubads().disableInitialLoad();
#                 googletag.pubads().collapseEmptyDivs();
#
#                         googletag.pubads().setTargeting('pagetype', ['homepage']);
#
#                     googletag.pubads().setTargeting('usertype', ['nonsubscriber']);
#
#                 if (typeof enhance !== 'undefined' && typeof enhance.cookie === 'function') {
#                     var etear = enhance.cookie('etsFlag');
#                     if (etear) {
#                         googletag.pubads().setTargeting('msrc', decodeURIComponent(etear));
#                     }
#                     var bluekai = enhance.cookie('bkuuid');
#                     if (bluekai) {
#                         googletag.pubads().setTargeting('bkuuid', bluekai);
#                     }
#                     var kruxId = enhance.cookie('kuid');
#                     if (kruxId) {
#                         googletag.pubads().setTargeting('kuid', kruxId);
#                     }
#                     var kruxSegs = enhance.cookie('ksg');
#                     if (kruxSegs) {
#                         googletag.pubads().setTargeting('ksg', kruxSegs);
#                     }
#                     var newsId = enhance.cookie('_ncg_id_');
#                     if (newsId) {
#                         googletag.pubads().setTargeting('news_id', newsId);
#                     }
#                 }
#
#                 // logic stolen from view mode code in marketwatch.js
#                 googletag.pubads().setTargeting('breakpoint', window.__mwads.breakpoints[window.getComputedStyle(document.body, '::after').getPropertyValue('content').replace(/\"/g, '')]);
#
#                 googletag.enableServices();
#             });
#
#         })();MarketWatch LogoGo to the homepage..mw1{fill:#ffffff;}
# 	.mw2{fill:#00AC4E;}LatestWatchlistMarketsInvestingBarron'sPersonal FinanceEconomyRetirementCoronavirusVideo CenterCommentaryMoreAccount SettingsLog InSign Upgoogletag.cmd.push(function() {
#                             window.__mwads.slots['ad-bulletin'] = googletag.defineSlot('/2/marketwatch.com/bulletin', [[140,31]], 'ad-bulletin')
#                                 .defineSizeMapping([[[640, 0], [[140,31]]],[[0, 0], []]])
#                                 .addService(googletag.pubads())
#                                     .setTargeting('adlocation', ['BULLETIN'])
#                                     .setTargeting('alert', ['volatility050','green'])
#                             ;googletag.display('ad-bulletin');
#                         });googletag.cmd.push(function() {
#                             window.__mwads.slots['ad-navigation'] = googletag.defineSlot('/2/marketwatch.com/nav_sponsor', [[280,40]], 'ad-navigation')
#                                 .defineSizeMapping([[[640, 0], [[280,40]]],[[0, 0], []]])
#                                 .addService(googletag.pubads())
#                                     .setTargeting('adlocation', ['NAVSPONSOR'])
#                                     .setTargeting('alert', ['volatility050','green'])
#                             ;googletag.display('ad-navigation');
#                         });HomeLatest NewsWatchlistMarketsU.S. MarketsCanadaEurope & Middle EastAsiaEmerging MarketsLatin AmericaMarket DataInvestingBarron'sBest New IdeasStocksIPOsMutual FundsETFsOptionsBondsCommoditiesCurrenciesCryptocurrenciesFuturesFinancial Adviser CenterCannabisBarron'sEconomy & PoliticsCoronavirusCapitol ReportTrump TodayElection 2020The Federal ReserveEconomic ReportRex NuttingBrexitU.S. Economic CalendarPersonal FinanceBest New Ideas in HealthThe MoneyistGifts That Pay OffSpending & SavingRetirementTaxesCredit CardsCareersTravelReal EstateReal Estate ListingsFamily FinanceLove & MoneyMoneyishRetirementBest New Ideas in RetirementEstate PlanningFIRETaxesSocial SecurityReal EstateRetirement PlannerWhere Should I Retire?Virtual Stock ExchangeVideoSectorWatchThe MoneyistGetting to Work WithLove & MoneyExplainomicsGood CompanyOpinionMarketPlaceOnline CoursesConsumer ProductsInsuranceNewsletter CenterPremium NewslettersRetirement WeeklyThe Technical IndicatorRevolution InvestingOptions TraderResearch & ToolsWatchlistStock ScreenerEarnings CalendarMarket ScreenerIPO CalendarPremarket ScreenerOptions CalendarAfter Hours ScreenerCurrency ToolsMutual Fund ScreenerUpgrades & DowngradesMutual Fund ComparisonEconomic CalendarCDsSavings AccountsMortgage RatesWhere Should I Retire?Retirement PlannerSign UpLog InProfile SettingsEmail & AlertsWatchlistGamesUSEuropeAsiaFXRatesFuturesCryptoFTSE 100-0.16%DAX0.15%CAC 40-0.21%FTSE MIB-0.61%IBEX 35-1.89%Stoxx 600-0.28%USEuropeAsiaFXRatesFuturesCryptoRange1D5D1M3M6M1Y2YFTSE 1006,113.84-9.98-0.16%DAX12,856.8018.740.15%CAC 404,946.16-10.27-0.21%FTSE MIB19,953.59-121.68-0.61%IBEX 357,157.10-137.60-1.89%Stoxx 600366.25-1.04-0.28%S&P 500 MoversBIIB4.2XLNX4.0SWKS3.6NEM3.5AEP-8.0HAS-7.3CCL-4.3MGM-4.0Latest NewsAll Times Eastern10:04aDeodorant sales fall due to social distancing but locked down consumers send ice-cream sales soaring, says Unilever10:03aBarron'sU.S. Stocks Gain Ahead of Busy Earnings Week10:01aAlphabet stock price target raised to $1,700 from $1,500 at MKM Partners10:00aUpdatedPfizer Reports Earnings Tomorrow. Here’s What to Expect.10:00aTarga Resources downgraded to neutral from buy at Seaport Global10:00aOld Navy partners with PopSugar for limited-edition tween collection9:57aUpdatedAmerican Airlines stock surges after Raymond James analyst backs away from bearish stance9:56aUpdatedBillionaire investor Ray Dalio fears for the dollar and the ‘soundness of our money,’ and here’s why9:52aBreakingDow's 75-point jump highlighted by gains for Dow Inc., Apple Inc. shares9:49aUpdatedDow, S&P 500 tread water as investors eye stimulus progress, await earnings floodto be replacedWatch NowThe Co-Founder of AOL Calls on Congressgoogletag.cmd.push(function() {
#                             window.__mwads.slots['ad-nasdaq-show'] = googletag.defineSlot('/2/marketwatch.com/sponsor_video_banner', [[140,31]], 'ad-nasdaq-show')
#                                 .defineSizeMapping([[[640, 0], [[140,31]]],[[0, 0], [[80,20]]]])
#                                 .addService(googletag.pubads())
#                                     .setTargeting('adlocation', ['MKTBRIEFLOGO'])
#                                     .setTargeting('alert', ['volatility050','green'])
#                             ;googletag.display('ad-nasdaq-show');
#                         });googletag.cmd.push(function() {
#                                 window.__mwads.slots['ad-banner'] = googletag.defineSlot('/2/marketwatch.com/frontpage', [[728,90],[970,90],[970,66],[970,250]], 'ad-banner')
#                                     .defineSizeMapping([[[960, 0], [[728,90],[970,90],[970,66],[970,250]]],[[0, 0], []]])
#                                     .addService(googletag.pubads())
#                                         .setTargeting('adlocation', ['BANNERTOP'])
#                                         .setTargeting('alert', ['volatility050','green'])
#                                 ;googletag.display('ad-banner');
#                             });Latest NewsCoronavirus UpdateS&P 500 FuturesAmazonAppleBoeingDisneyFacebookEarnings WatchMicrosoftTeslaIBMCoca-ColaChipotleIntelMattelBillionaire investor Ray Dalio warns U.S.-China conflict could become a ‘capital war’ that hits the dollarBillionaire investor Ray Dalio warns U.S.-China conflict could become a ‘capital war’ that hits the dollarHere’s what a falling U.S. dollar means for the stock marketU.S. consulate personnel in Chengdu pack up and leave as China takes controlOpinion:Wall Street turns a blind eye to atrocities committed in ChinaGold shoots $40 higher to fresh record above $1,900Bitcoin surges over $10,000, could surpass $15,000, digital-currency experts saygoogletag.cmd.push(function() {
#                                 window.__mwads.slots['ad-lead-display-ad'] = googletag.defineSlot('/2/marketwatch.com/frontpage', [], 'ad-lead-display-ad')
#                                     .defineSizeMapping([[[640, 0], []],[[0, 0], [[300,250]]]])
#                                     .addService(googletag.pubads())
#                                         .setTargeting('adlocation', ['MOBILEMPU'])
#                                         .setTargeting('alert', ['volatility050','green'])
#                                 ;googletag.display('ad-lead-display-ad');
#                             });His fund is up 60% this year after he called the March bottom — now, he sees potential for a ‘severe collapse’Opinion:This index tracks economic uncertainty — and it’s pretty clear about what’s in store for stocks through Election DayOpinion:What would Sir John do? How to use Templeton’s 16 rules for investment success in today’s stock marketOpinion:Value stocks really may have lost their mojo this time — and growth stocks are gaining from itGlobal cases of COVID-19 top 16.2 million, 648,966 deaths and Florida’s case tally tops New York’sThe global tally for confirmed cases of the coronavirus that causes COVID-19 climbed above 16.2 million on Monday, according to data aggregated by Johns Hopkins University, and the death toll rose to 648,966. At least 9.4 million people have recovered. The U.S. case tally climbed to 4.23 million and the death toll rose to 146,935. Florida now has the second highest number of cases after California, and both those states have more than early hot spot New York. On a visit to Kentucky, Dr. Deborah Birx, coordinator of the White House Task Force created to manage the pandemic, said that state and several others should reimpose shutdowns on bars and limit indoor gatherings to control the spread.  Brazil is second to the U.S. with 2.4 million cases and 87,004 deaths. India is third measured by cases at 1.4 million, followed by Russia with 811,073 and South Africa with 445,433. The U.K. has 301,020 cases and 45,837 fatalities, the highest in Europe and third highest in the world. China, where the illness was first reported late last year, has 86,570 cases after adding more than 200 over the weekend, and 4,652 fatalities.Moderna's stock rallies 11% as it begins Phase 3 trial for COVID-19 vaccineShares of Moderna Inc. undefined gained 11.3% in premarket trading on Monday after the company said it started to dose participants in the Phase 3 trial for its experimental COVID-19 vaccine. Moderna also announced Sunday that it will receive additional funding of up to $472 million of its vaccine candidate from the Biomedical Advanced Research and Development Authority to help fund the addition of more participants in the late-stage trial. (Moderna previously announced it had been awarded $483 million in federal funding to support clinical development of the vaccine.) The Phase 3 randomized, placebo-controlled trial, which is being conducted with the National Institute of Allergy and Infectious Diseases, is expected to enroll up to 30,000 people, who will receive a 100 microgram dose of the investigational vaccine. The primary endpoint is preventing symptomatic COVID-19 disease, and the secondary endpoints are preventing severe forms of COVID-19 that require hospitalization and preventing contracting the virus altogether. Moderna's stock has soared 274.2% since the start of the year, while the S&P 500 undefined is down 0.4%.MRNA4.80%Deodorant sales fall due to social distancing but locked down consumers send ice-cream sales soaring, says UnileverJohn Lewis crosses Edmund Pettus Bridge in Selma, Ala., one final timeWhite House officials suggest breaking new coronavirus relief package into smaller piecesMnuchin: Virus aid package soon, $1,200 checks by August‘They are still citizens, so they should be able to access that money’: Inside the quest to claim stimulus checks before the deadlineOpinion:Trump is losing to Biden in voter polls — and here’s how this will play out on Election Day8 in 10 Americans say country is heading down wrong path, new poll findsPresident Trump to Dave Portnoy: The 401(k) investors who followed my advice are ‘doing phenomenally’Trump's national-security adviser has coronavirus: reportsBig Tech’s big test arrives in the busiest week of earnings seasonCongress has a million-plus documents from Big Tech antitrust investigation, and are ready to grill big-name CEOsS&P 500 earnings have been as bad as feared, even as the beat rate has improvedBoeing earnings  ...
#                             window.__mwads.slots['ad-curated-native'] = googletag.defineSlot('/2/marketwatch.com/frontpage', [[1,2],['fluid']], 'ad-curated-native')
#                                 .defineSizeMapping([])
#                                 .addService(googletag.pubads())
#                                     .setTargeting('ntvPlacement', ['{Model.NewsHole[0].LayoutId:choose(A|B|C|D):1088448|1088449|1091804|1091805}'])
#                                     .setTargeting('pagetemplate', ['layout{Model.NewsHole[0].LayoutId}'])
#                                     .setTargeting('alert', ['volatility050','green'])
#                             ;googletag.display('ad-curated-native');
#                         });Closed Apple Stores could change iPhone buying habits, but there’s reason for hope amid pandemicAmazon stock will rise because consumer habits are changing, maybe for goodFacebook has weathered many storms, but the latest are coming for its coreMuted spending growth in pandemic doesn’t cancel big opportunities for payments companiesMy boyfriend is buying a house and does not want me to have equity. I’m moving in with him and selling my home — what should I do with the proceeds?‘I don’t want to help pay the mortgage if I’m not receiving equity. I’m more than happy to pay for other things.’Domestic abusers are taking survivors’ stimulus checks — and lawmakers want the IRS to do something about itDomestic-violence survivors often use cash infusions as a springboard toward safety.‘Uncomfortably close’: Hurricane Douglas bears down on HawaiiPolice and protesters clash in violent weekend across the U.S.Google to keep employees at home until next year, Wall Street Journal reportsAlphabet Inc.'s undefined Google has told its employees that it will extend its work-from-home order until at least July 2021 in the face of the COVID-19 pandemic, according to a report in The Wall Street Journal, making the internet search giant the first to push back its back-to-normal plans that far. The move will affect nearly all of its roughly 200,000 employees across Google's parent, Alphabet, the WSJ report said. Google had previously told its staff to expect to return to the offices as early as the beginning of January, the report said. The stock, which gained 0.9% in premarket trading, has advanced 12.6% year to date through Friday, while the S&P 500 undefined has slipped 0.5%.GOOGL1.73%PwC chair Kevin Ellis joins Twitter boycott over anti-Semitic posts from WileyLead judge of the BBC series The Apprentice and chair of Amshold Group Lord Sugar, the personal finance journalist Martin Lewis and the Lloyds Bank Foundation also joined the campaign of social media silenceOscar winner, Hollywood icon Olivia de Havilland dies at 104AstraZeneca, Daiichi Sankyo in $6 billion oncology dealAstraZeneca PLC said Monday that it has entered into an oncology collaboration with Daiichi Sankyo Co. worth up to $6 billion that it said could redefine treatment standards in lung, breast and multiple other cancers.Joe Rogan is bailing on California after scoring $100 million dealgoogletag.cmd.push(function() {
#                                 window.__mwads.slots['ad-display-ad'] = googletag.defineSlot('/2/marketwatch.com/frontpage', [[300,250],[300,600],[300,1050],[ 300,1850]], 'ad-display-ad')
#                                     .defineSizeMapping([[[640, 0], [[300,250],[300,600],[300,1050],[ 300,1850]]],[[0, 0], [[300,250]]]])
#                                     .addService(googletag.pubads())
#                                         .setTargeting('adlocation', ['FIRSTMPU'])
#                                         .setTargeting('alert', ['volatility050','green'])
#                                 ;googletag.display('ad-display-ad');
#                             });Coronavirus UpdatesGet the latest news from MarketWatch on COVID-19.Global cases of COVID-19 top 16.2 million, 648,966 deaths and Florida’s case tally tops New York’sThis is the biggest mistake people make while wearing a face maskRule change for how hospitals report coronavirus data to government comes under fireAbigail Disney ‘confused’ by Disney reopening its Florida theme parks as coronavirus cases spikeBarron'sSerious investors read Barron's. Make the smartest investment decisions with access to Barron's in-depth analysis and unrivaled market predictions.U.S. Stocks Gain Ahead of Busy Earnings WeekUnder Armour Stock Falls Following SEC Enforcement NoticeEuropean Companies Are Beating Earnings Estimates but Stock Price Reaction Is MutedEuropean companies are beating expectations so far in earnings season but price reaction has been negatively skewed, Morgan Stanley strategists say.German Software Giant SAP Announces IPO for U.S. Arm Qualtrics. Shares Are Climbing.SAP will remain the majority owner of Qualtrics, the software company that allows businesses to track customer and employee experiences.Subscribe NowSubscribe today for combined access to MarketWatch and Barron’s.Most Populargoogletag.cmd.push(function() {
#                             window.__mwads.slots['ad-most-popular'] = googletag.defineSlot('/2/marketwatch.com/sponsor_mostpopular_homepagelogo', [[140,31]], 'ad-most-popular')
#                                 .defineSizeMapping([[[640, 0], [[140,31]]],[[0, 0], [[80,20]]]])
#                                 .addService(googletag.pubads())
#                                     .setTargeting('adlocation', ['MOSTPOPULAR'])
#                                     .setTargeting('alert', ['volatility050','green'])
#                             ;googletag.display('ad-most-popular');
#                         });His fund is up 60% this year after he called the March bottom — now, he sees potential for a ‘severe collapse’Here’s what a falling U.S. dollar means for the stock marketU.S. stock futures rise ahead of big earnings weekJoe Rogan is bailing on California after scoring $100-million dealFauci tells MarketWatch his one big lesson from the COVID-19 pandemic — and why he won’t fly or eat outThe 10 coolest things about the new Ford BroncoModerna secures another $472 million from U.S. for COVID-19 vaccine effortsPresident Trump to Dave Portnoy: The 401(k) investors who followed my advice are ‘doing phenomenally’Elon Musk: ‘Another government stimulus package is not in the best interests of the people’Moderna's stock surges as new funding sets Phase 3 trial of COVID-19 vaccine candidate to start 'immediately'Partner Centergoogletag.cmd.push(function() {
#                             window.__mwads.slots['ad-broker-button-1'] = googletag.defineSlot('/2/brokerbuttons.marketwatch.com/frontpage', [[120,60]], 'ad-broker-button-1')
#                                 .defineSizeMapping([])
#                                 .addService(googletag.pubads())
#                                 .setTargeting('pos', '1')
#                                     .setTargeting('adlocation', ['BROKER1'])
#                                     .setTargeting('alert', ['volatility050','green'])
#                             ;googletag.display('ad-broker-button-1');
#                         });googletag.cmd.push(function() {
#                             window.__mwads.slots['ad-broker-button-2'] = googletag.defineSlot('/2/brokerbuttons.marketwatch.com/frontpage', [[120,60]], 'ad-broker-button-2')
#                                 .defineSizeMapping([])
#                                 .addService(googletag.pubads())
#                                 .setTargeting('pos', '2')
#                                     .setTargeting('adlocation', ['BROKER2'])
#                                     .setTargeting('alert', ['volatility050','green'])
#                             ;googletag.display('ad-broker-button-2');
#                         });googletag.cmd.push(function() {
#                             window.__mwads.slots['ad-broker-button-3'] = googletag.defineSlot('/2/brokerbuttons.marketwatch.com/frontpage', [[120,60]], 'ad-broker-button-3')
#                                 .defineSizeMapping([])
#                                 .addService(googletag.pubads())
#                                 .setTargeting('pos', '3')
#                                     .setTargeting('adlocation', ['BROKER3'])
#                                     .setTargeting('alert', ['volatility050','green'])
#                             ;googletag.display('ad-broker-button-3');
#                         });googletag.cmd.push(function() {
#                             window.__mwads.slots['ad-broker-button-4'] = googletag.defineSlot('/2/brokerbuttons.marketwatch.com/frontpage', [[120,60]], 'ad-broker-button-4')
#                                 .defineSizeMapping([])
#                                 .addService(googletag.pubads())
#                                 .setTargeting('pos', '4')
#                                     .setTargeting('adlocation', ['BROKER4'])
#                                     .setTargeting('alert', ['volatility050','green'])
#                             ;googletag.display('ad-broker-button-4');
#                         });Trending VideoGo to Video Center80% of older Americans can't afford to retire - COVID-19 isn't helpingWant more videos from MarketWatch? Subscribe to our channel on YouTube!80% of older Americans can't afford to retire - COVID-19 isn't helpingU.S. Fighter Jet Flies Close to Iranian Passenger PlaneWhat you need to know about bank stocks right nowMassive Floods Add More Uncertainty to China’s EconomyMore than 20 million Americans may be evicted by SeptemberHow to pick sectors to invest in amid a COVID-19 resurgenceNovogratz's New Bitcoin PartnershipParler App Grows as Conservatives Debate Free Speech Over Social MediaTrump Cancels GOP Convention Events in FloridaWhy Some States Are Narrowing Access to Covid-19 TestsMarketBriefWatch NowSectorWatchWatch NowExplainomicsWatch NowMarketsgoogletag.cmd.push(function() {
#                                 window.__mwads.slots['ad-markets-sponsor'] = googletag.defineSlot('/2/marketwatch.com/sponsor_homepagetile_markets', [[140,31]], 'ad-markets-sponsor')
#                                     .defineSizeMapping([[[640, 0], [[140,31]]],[[0, 0], [[80,20]]]])
#                                     .addService(googletag.pubads())
#                                         .setTargeting('alert', ['volatility050','green'])
#                                 ;googletag.display('ad-markets-sponsor');
#                             });Dow, S&P 500 kick off muted trade on Monday but tech stocks try to resume climb as gold prices surge to recordsU.S. stocks on Monday opened mixed, with the Dow and S&P 500 under pressure, as investors watched for progress toward another coronavirus rescue pr...DJIA0.39%COMP1.17%10-year Treasury yield lingers below 0.60% as investors eye extension of fiscal supportU.S. Treasury yields retreat early Monday amid worries that Congressional infighting could endanger the prospect of additional fiscal stimulus meas...BX:TMUBMUSD02Y0.149%BX:TMUBMUSD10Y0.594%Airlines slump in London as Ryanair CEO criticizes U.K. government quarantine on SpainThe London stock market was a tale of two sectors on Monday, with the travel sector getting hit hard by the U.K. decision to quarantine visitors fr...Bitcoin surges over $10,000, could surpass $15,000, digital-currency experts sayBTCUSD4.50%BTC.18.58%Spanish quarantine to exclude Canary Islands and Balearics: reportThe quarantine imposed on Spanish visitors returning to the U.K. will be lifted for those returning from Canary Islands or the Balearics, The Sun r...RYAAY-3.44%UK:RYA-4.31%Gold Soars, Hasbro Drops, and the Dow Edges UpDJIA0.39%HAS-7.29%Watchlistgoogletag.cmd.push(function() {
#                             window.__mwads.slots['ad-watchlist-sponsor'] = googletag.defineSlot('/2/marketwatch.com/sponsor_homepagetile_watchlist', [[140,31]], 'ad-watchlist-sponsor')
#                                 .defineSizeMapping([[[640, 0], [[140,31]]],[[0, 0], [[80,20]]]])
#                                 .addService(googletag.pubads())
#                                     .setTargeting('alert', ['volatility050','green'])
#                             ;googletag.display('ad-watchlist-sponsor');
#                         });Customize MarketWatchHave Watchlists? Log in to see them here or sign up to get started.Create Account… orLog InAdd TickerSymbolLastChangeChgChange %Chg %Volume(Go to Watchlist)googletag.cmd.push(function() {
#                             window.__mwads.slots['ad-watchlist-bottom'] = googletag.defineSlot('/2/marketwatch.com/sponsor_homepagetile_watchlist', [[160,21]], 'ad-watchlist-bottom')
#                                 .defineSizeMapping([[[640, 0], [[160,21]]],[[0, 0], []]])
#                                 .addService(googletag.pubads())
#                                     .setTargeting('alert', ['volatility050','green'])
#                             ;googletag.display('ad-watchlist-bottom');
#                         });No Items in WatchlistThere are currently no items in this Watchlist.Add TickerNo Saved WatchlistsCreate a list of the investments you want to track.Create Watchlist…orlearn moreUh ohSomething went wrong while loading Watchlist.Go to WatchlistRecently Viewed TickersNo Recent TickersVisit a quote page and your recently viewed tickers will be displayed here.Search Tickersgoogletag.cmd.push(function() {
#                                 window.__mwads.slots['ad-bottom-display-ad'] = googletag.defineSlot('/2/bottom.marketwatch.com/frontpage', [[300,250],[336,280],[ 300,600]], 'ad-bottom-display-ad')
#                                     .defineSizeMapping([[[640, 0], [[300,250],[ 336,280],[ 300,600]]],[[0, 0], []]])
#                                     .addService(googletag.pubads())
#                                         .setTargeting('adlocation', ['SECONDMPU'])
#                                         .setTargeting('alert', ['volatility050','green'])
#                                 ;googletag.display('ad-bottom-display-ad');
#                             });Investinggoogletag.cmd.push(function() {
#                                 window.__mwads.slots['ad-investing-sponsor'] = googletag.defineSlot('/2/marketwatch.com/sponsor_homepagetile_investing', [[140,31]], 'ad-investing-sponsor')
#                                     .defineSizeMapping([[[640, 0], [[140,31]]],[[0, 0], [[80,20]]]])
#                                     .addService(googletag.pubads())
#                                         .setTargeting('alert', ['volatility050','green'])
#                                 ;googletag.display('ad-investing-sponsor');
#                             });Old Navy partners with PopSugar for limited-edition tween collectionOld Navy said Monday that it has partnered with beauty, fashion and entertainment blog PopSugar for a limited-edition tween collection, that will i...GPS-1.19%SPX0.53%American Airlines stock surges after Raymond James analyst backs away from bearish stanceShares of American Airlines Group Inc.  surged 3.3% in premarket trading Monday, after Raymond James analyst Savanthi Syth backed away from her bea...SPX0.53%AAL2.52%Dow, S&P 500 tread water as investors eye stimulus progress, await earnings floodDJIA0.39%COMP1.17%Facebook pushes earnings report to Thursday after Big Tech hearing is rescheduledFacebook Inc.  said Monday that it plans to report second-quarter earnings Thursday instead of Wednesday "due to a scheduling conflict." Chief Exec...AAPL1.95%AMZN1.86%Walgreens CEO to step downShares of Walgreens Boots Alliance Inc.  were down 0.2% in premarket trading on Monday after the pharmacy chain said CEO Stefano Pessina was steppi...SPX0.53%WBA-2.37%ANGI Homeservices and Lowe's announce partnershipLowe's Cos.  and ANGI Homeservices Inc.'s  HomeAdvisor announced a new partnership Monday. The two companies have arranged for Lowe's for Pros Loya...LOW1.31%SPX0.53%Financial Adviser CenterAnnuities can help your retirement portfolio stay afloat. These are the best onesOpinion:Seniors who rely on dividend income may be in for some lean timesDividend cuts are adding to retirees’ painOpinion:Living in retirement during COVID-19? How to keep your coolPeople in or close to retirement have specific needs and concernsOpinion:There is more to picking a place to retire than low taxes — avoid these 5 expensive mistakesHow to build an investment portfolio that supports racial justicegoogletag.cmd.push(function() {
#                                 window.__mwads.slots['ad-financial-adviser-sponsor'] = googletag.defineSlot('/2/marketwatch.com/frontpage/facenter', [[140,31]], 'ad-financial-adviser-sponsor')
#                                     .defineSizeMapping([[[640, 0], [[140,31]]],[[0, 0], [[80,20]]]])
#                                     .addService(googletag.pubads())
#                                         .setTargeting('alert', ['volatility050','green'])
#                                 ;googletag.display('ad-financial-adviser-sponsor');
#                             });googletag.cmd.push(function() {
#                                 window.__mwads.slots['ad-belt'] = googletag.defineSlot('/2/bottom.marketwatch.com/frontpage', [[970,250],[728,90],[970,66],[970,90]], 'ad-belt')
#                                     .defineSizeMapping([[[960, 0], [[970,250],[728,90],[970,66],[970,90]]],[[0, 0], []]])
#                                     .addService(googletag.pubads())
#                                         .setTargeting('adlocation', ['BANNERBOTTOM'])
#                                         .setTargeting('alert', ['volatility050','green'])
#                                 ;googletag.display('ad-belt');
#                             });Economy & PoliticsDurable-goods orders climb 7.3% in June as auto maker surge offsets Boeing weaknessWall Street turns a blind eye to atrocities committed in ChinaTrump's national-security adviser has coronavirus: reportsPresident Donald Trump's national-security adviser, Robert O'Brien, has tested positive for coronavirus, according to published reports. He came down with the virus after a family event and has been isolating at home while...Congress has a million-plus documents from Big Tech antitrust investigation, and are ready to grill big-name CEOsWatch out: inflation could be lurking on the other side of the pandemicThis week we’ll learn the size of the hole the U.S. economy fell into when COVID-19 struckMoney alone won’t close America’s racial and wealth gaps. We first need to wipe out the value gap — ‘the belief that white people matter more than others’Personal Financegoogletag.cmd.push(function() {
#                                 window.__mwads.slots['ad-personal-finance-sponsor'] = googletag.defineSlot('/2/marketwatch.com/sponsor_homepagetile_pf', [[140,31]], 'ad-personal-finance-sponsor')
#                                     .defineSizeMapping([[[640, 0], [[140,31]]],[[0, 0], [[80,20]]]])
#                                     .addService(googletag.pubads())
#                                         .setTargeting('alert', ['volatility050','green'])
#                                 ;googletag.display('ad-personal-finance-sponsor');
#                             });California, New Jersey and New York City pause indoor dining. Fauci says it’s more dangerous than outdoors — here’s why‘We’re moving back into a modification mode of our original stay-at-home order,” Gov. Gavin Newsom, a Democrat, said. ‘This continues to be a deadly disease.’The 10 coolest things about the new Ford BroncoWhy is it so hard to find a balance transfer card right now?Safety and customer service: Which airlines are doing best?Today's Interest RatesMortgageEquitySavingsAuto30 yr fixed Jumbo3.18%30 yr fixed3.14%15 yr fixed2.75%10 yr fixed2.73%30 yr fixed refi3.20%15 yr fixed refi2.77%5/1 ARM3.28%5/1 ARM refi3.33%National averages fromBankrate.com$30K HELOC1.99%$50K HELOC5.00%$75K HELOC1.99%$100K HELOC5.00%$30K Home Equity Loan5.24%$50K Home Equity Loan3.74%$75K Home Equity Loan3.74%$100K Home Equity Loan4.12%National averages fromBankrate.com5 yr CD0.69%2 yr CD0.50%1 yr CD0.46%MMA $10K+0.19%MMA $50K+0.26%MMA Savings0.26%MMA Savings Jumbo0.28%National averages fromBankrate.com60 Mo Used Car4.40%48 Mo Used Car4.67%36 Mo Used Car4.74%72 Mo New Car4.23%60 Mo New Car4.45%48 Mo New Car4.26%60 Mo Auto Refi4.50%36 Mo Auto Refi4.25%National averages fromBankrate.comThe Moneyistgoogletag.cmd.push(function() {
#                                 window.__mwads.slots['ad-the-moneyist-sponsor'] = googletag.defineSlot('/2/marketwatch.com/sponsor_homepagetile_moneyologist', [[140,31]], 'ad-the-moneyist-sponsor')
#                                     .defineSizeMapping([[[640, 0], [[140,31]]],[[0, 0], [[80,20]]]])
#                                     .addService(googletag.pubads())
#                                         .setTargeting('alert', ['volatility050','green'])
#                                 ;googletag.display('ad-the-moneyist-sponsor');
#                             });Quentin Fottrell answers your questions about inheritance, tipping, weddings, re-gifting, or any tricky money issues relating to family and friends. Have a question?Send it to the Moneyist.‘I’m having a hard time understanding how earning over $200,000 a year is too much to qualify for a decent stimulus check’I told my unemployed tenant about jobs. He said they don’t pay enough, and sits at home smoking weed. Now he wants a discount. What do I do?My father died from COVID-19, and left no will. My stepmother threatened to sell our family heirlooms — unless we sign over our claim to his estate. What can we do?Should I tell my sister that her husband, a notorious spender, has a secret credit card?Retirementgoogletag.cmd.push(function() {
#                                 window.__mwads.slots['ad-retirement-sponsor'] = googletag.defineSlot('/2/marketwatch.com/sponsor_homepagetile_retirement', [[140,31]], 'ad-retirement-sponsor')
#                                     .defineSizeMapping([[[640, 0], [[140,31]]],[[0, 0], [[80,20]]]])
#                                     .addService(googletag.pubads())
#                                         .setTargeting('alert', ['volatility050','green'])
#                                 ;googletag.display('ad-retirement-sponsor');
#                             });Are you facing early retirement? Here’s how to prepareI’m a 32-year-old stay-at-home mom, and my husband earns $150,000 a year. Will I ever be able to enjoy a retirement?I want year-round outdoor living — dry summers and no snow — on $4,000 a month. Where should I retire?The military is giving me retirement and disability pay — but will it be enough to retire at 48?Real EstateAmerica is facing an eviction crisis as moratoriums expire: ‘This is a potential catastrophe’Democratic lawmakers have proposed legislation to extend and to expand the federal moratorium on evictions, which is set to expire in just a few days.The feared jumbo mortgage debacle is here — thanks to the coronavirus — and ready to pound the housing marketThousands in Silicon Valley in danger of eviction as end of California moratorium nearsLook what happened to home prices when the coronavirus sent stocks into a bear market‘It’s a tax on being Black in this country’ — 5 ways racism is embedded in the housing industryMansion GlobalConnecting affluent buyers with luxury listings.A 40-Acre Compound in the Heart of New York’s Hudson ValleyWhen it Comes to Property, Covid-19 Has Been ‘A Time to Reflect’Take Your Home Into the FutureThe Best of Smart Bathroom TechnologyPartner Content××var utag_data = {
# "page_access":"free","page_content_source":"MarketWatch","page_site":"MarketWatch","page_site_product":"MW","page_content_language":"en-US","page_content_region":"North_America_USA","page_content_type":"Home","user_exp":"default","reengagement_refresh":"off","user_type":"nonsubscriber","user_tags":"","page_section":"Home Page","page_id":"/","page_ad_zone":"frontpage","page_subsection":"Home Page","cms_name":"Peavey"};
# var utag_dataOriginal = {};
# (function () {
#     for (var prop in utag_data) {
#         utag_dataOriginal[prop] = utag_data[prop];
#     }
#     Object.freeze(utag_dataOriginal);
# })();var trackingPageInfo = {
#     action: 'Page'
# };Back to TopMarketWatch LogoGo to the homepage..mw1{fill:#ffffff;}
# 	.mw2{fill:#00AC4E;}Copyright © 2020 MarketWatch, Inc. All rights reserved.By using this site you agree to theSubscriber Agreement & Terms of UseUpdated 03/26/2020Privacy NoticeandCookie Notice.FacebookTwitterLinkedinMarketWatchHelpFeedbackNewsroom RosterVirtual Stock ExchangeBigChartsCompanyDow JonesCode of ConductCorrectionsReprints & LicensingYour Ad ChoicesDow Jones NetworkThe Wall Street JournalBarron'sFinancial News Londonrealtor.comMansion GlobalKnewzIntraday Data provided byFACTSETand subject toterms of use.
#           Historical and current end-of-day data provided byFACTSET.
#           All quotes are in local exchange time.
#           Real-time last sale data for U.S. stock quotes reflect trades reported through Nasdaq only.
#           Intraday data delayed at least 15 minutes or per exchange requirements.Trending TickersPowered byDKNG-1.78%GLD1.86%ACI-4.47%WHLM109.64%AMD0.22%googletag.cmd.push(function() {
#                             window.__mwads.slots['ad-trending-tickers'] = googletag.defineSlot('/2/marketwatch.com/sponsor_trendingtickers', [[140,31]], 'ad-trending-tickers')
#                                 .defineSizeMapping([[[960, 0], [[140,31]]],[[0, 0], []]])
#                                 .addService(googletag.pubads())
#                                     .setTargeting('adlocation', ['TRENDINGTICKERS'])
#                                     .setTargeting('alert', ['volatility050','green'])
#                             ;googletag.display('ad-trending-tickers');
#                         });var blueGrass2SilentTest = {
#             enabled: false,
#             endpoint: 'https://mw-silent.bgdev.dowjones.io/bg2'
#         };window.__mwads=window.__mwads||{slots:{}},function(){if(!window.__mwads.gptEnabled)return void window.__mwads.log("GPT disabled");googletag.cmd.push(function(){googletag.pubads().addEventListener("slotRequested",function(e){performance.getEntriesByName("gpt-slotRequested").length||performance.mark("gpt-slotRequested"),e.slot.getSlotElementId()!==window.__mwads.mpuId||performance.getEntriesByName("gpt-mpuRequested").length||performance.mark("gpt-mpuRequested")}),googletag.pubads().addEventListener("slotRenderEnded",function(e){performance.getEntriesByName("gpt-slotRenderEnded").length||performance.mark("gpt-slotRenderEnded"),e.slot.getSlotElementId()!==window.__mwads.mpuId||performance.getEntriesByName("gpt-mpuRenderEnded").length||performance.mark("gpt-mpuRenderEnded");var t=document.getElementById(e.slot.getSlotElementId());t&&(t.parentElement.classList.remove("is-loading"),t.parentElement.classList.add("is-loaded"))}),googletag.pubads().addEventListener("slotOnload",function(e){performance.getEntriesByName("gpt-slotOnload").length||performance.mark("gpt-slotOnload"),e.slot.getSlotElementId()!==window.__mwads.mpuId||performance.getEntriesByName("gpt-mpuOnLoad").length||performance.mark("gpt-mpuOnLoad")})});var e,t=1e3,n=1e3,o=!1,a=function(e){return Object.keys(e).map(function(t){return e[t]})},i=function(e){return e.map(function(e){return e.getSlotElementId()})},r=function(e,t){return window.__mwads.slots.hasOwnProperty(t.getAttribute("id"))&&e.push(window.__mwads.slots[t.getAttribute("id")]),e},s={LOW:1,MEDIUM:2,HIGH:3},d=[],l={},c=[],u=0,f=s.HIGH,m=function(e,t,n){window.__mwads.log("add "+e+" display prereq with importance "+n),n>=f&&u++,c.push(function(o,a){t(o,g(e,n,a))})},g=function(e,t,n){return function(){window.__mwads.log("finished "+e+" display prereq with importance "+t),n(t)}},p=function(e){e&&e.forEach(function(e){window.__mwads.log("displayed "+e.getSlotElementId()),l[e.getSlotElementId()]=e})},w=function(e,t){if(!o)return void(d=d.concat(e));var a=u,s=e.reduce(r,[]),l=!1,m=function(e){!l&&e&&(l=!0,googletag.cmd.push(function(){window.__mwads.log("gpt refresh for "+i(e).join(",")),googletag.pubads().refresh(e),p(e)}))};if(c.length>0){window.__mwads.log("starting display prereqs...");for(var g=setTimeout(m.bind(s),n),w=0;w<c.length;w++)c[w](s,function(e){e>=f&&--a,0>=a&&(clearTimeout(g),window.__mwads.log("...finished display prereqs"),m(s))})}else window.__mwads.log("no display prereqs"),m(s)},h=[],_=0,y=s.HIGH,v=function(e,t,n){window.__mwads.log("add "+e+" load prereq with importance "+n),n>=y&&_++,h.push(function(){t(E(e,n))})},E=function(e,t){return function(){window.__mwads.log("finished "+e+" load prereq with importance "+t),t>=y&&0===--_&&b()}},b=function(){clearTimeout(e),window.__mwads.log("go ads, go"),o||(o=!0,w(d),d=[])};window.addEventListener("lazybeforeunveil",function(e){e.target.classList.contains("j-ad")&&w([e.target])}),googletag.cmd.push(function(){"undefined"!=typeof window.pxSegmentIDs&&a(window.__mwads.slots).forEach(function(e){window.__mwads.log("psg for "+e.getSlotElementId()),e.setTargeting("psg",window.pxSegmentIDs.split(","))})}),googletag.cmd.push(function(){var e=/curated--(A|B|C|D)/i;document.querySelectorAll(".component--curated").forEach(function(t){var n=t.querySelector(".is-native .j-ad");if(n&&window.__mwads.slots.hasOwnProperty(n.getAttribute("id"))){var o=e.exec(t.className);o&&o.length>1&&(window.__mwads.slots[n.getAttribute("id")].setTargeting("ntvPlacement",window.__mwads.curatedMap[o[1]]),window.__mwads.slots[n.getAttribute("id")].setTargeting("pagetemplate","layout"+o[1]))}})}),window.addEventListener("curatedUpdate",function(){var e=document.querySelector(".component--curated .is-native");e&&"undefined"!=typeof PostRelease&&"function"==typeof PostRelease.Start&&MarketWatch&&MarketWatch.Settings&&MarketWatch.Settings.snare&&PostRelease.Start({ptd:MarketWatch.Settings.snare.nativeIds})}),window.addEventListener("viewModeChanged",function(){googletag.cmd.push ...
# !function(e,t){var n=t(e,e.document);e.lazySizes=n,"object"==typeof module&&module.exports?module.exports=n:"function"==typeof define&&define.amd&&define(n)}(window,function(e,t){"use strict";if(t.getElementsByClassName){var n,o=t.documentElement,a=e.HTMLPictureElement&&"sizes"in t.createElement("img"),i="addEventListener",r="getAttribute",s=e[i],d=e.setTimeout,l=e.requestAnimationFrame||d,c=/^picture$/i,u=["load","error","lazyincluded","_lazyloaded"],f={},m=Array.prototype.forEach,g=function(e,t){return f[t]||(f[t]=new RegExp("(\\s|^)"+t+"(\\s|$)")),f[t].test(e[r]("class")||"")&&f[t]},p=function(e,t){g(e,t)||e.setAttribute("class",(e[r]("class")||"").trim()+" "+t)},w=function(e,t){var n;(n=g(e,t))&&e.setAttribute("class",(e[r]("class")||"").replace(n," "))},h=function(e,t,n){var o=n?i:"removeEventListener";n&&h(e,t),u.forEach(function(n){e[o](n,t)})},_=function(e,n,o,a,i){var r=t.createEvent("CustomEvent");return r.initCustomEvent(n,!a,!i,o||{}),e.dispatchEvent(r),r},y=function(t,o){var i;!a&&(i=e.picturefill||n.pf)?i({reevaluate:!0,elements:[t]}):o&&o.src&&(t.src=o.src)},v=function(e,t){return(getComputedStyle(e,null)||{})[t]},E=function(e,t,o){for(o=o||e.offsetWidth;o<n.minSize&&t&&!e._lazysizesWidth;)o=t.offsetWidth,t=t.parentNode;return o},b=function(t){var n,o=0,a=e.Date,i=function(){n=!1,o=a.now(),t()},r=function(){d(i)},s=function(){l(r)};return function(){if(!n){var e=125-(a.now()-o);n=!0,6>e&&(e=6),d(s,e)}}},z=function(){var a,u,f,E,z,C,S,I,M,N,R,L,q,B,H,P=/^img$/i,k=/^iframe$/i,T="onscroll"in e&&!/glebot/.test(navigator.userAgent),W=0,O=0,x=0,D=0,G=function(e){x--,e&&e.target&&h(e.target,G),(!e||0>x||!e.target)&&(x=0)},j=function(e,n){var a,i=e,r="hidden"==v(t.body,"visibility")||"hidden"!=v(e,"visibility");for(M-=n,L+=n,N-=n,R+=n;r&&(i=i.offsetParent)&&i!=t.body&&i!=o;)r=(v(i,"opacity")||1)>0,r&&"visible"!=v(i,"overflow")&&(a=i.getBoundingClientRect(),r=R>a.left&&N<a.right&&L>a.top-1&&M<a.bottom+1);return r},F=function(){var e,t,i,s,d,l,c,m,g;if((z=n.loadMode)&&8>x&&(e=a.length)){t=0,D++,null==B&&("expand"in n||(n.expand=o.clientHeight>600?o.clientWidth>860?500:410:359),q=n.expand,B=q*n.expFactor),B>O&&1>x&&D>3&&z>2?(O=B,D=0):O=z>1&&D>2&&6>x?q:W;for(;e>t;t++)if(a[t]&&!a[t]._lazyRace)if(T)if((m=a[t][r]("data-expand"))&&(l=1*m)||(l=O),g!==l&&(S=innerWidth+l*H,I=innerHeight+l,c=-1*l,g=l),i=a[t].getBoundingClientRect(),(L=i.bottom)>=c&&(M=i.top)<=I&&(R=i.right)>=c*H&&(N=i.left)<=S&&(L||R||N||M)&&(f&&3>x&&!m&&(3>z||4>D)||j(a[t],l))){if(Q(a[t]),d=!0,x>9)break}else!d&&f&&!s&&4>x&&4>D&&z>2&&(u[0]||n.preloadAfterLoad)&&(u[0]||!m&&(L||R||N||M||"auto"!=a[t][r](n.sizesAttr)))&&(s=u[0]||a[t]);else Q(a[t]);s&&!d&&Q(s)}},$=b(F),U=function(e){p(e.target,n.loadedClass),w(e.target,n.loadingClass),h(e.target,U)},Y=function(e,t){try{e.contentWindow.location.replace(t)}catch(n){e.src=t}},J=function(e){var t,o,a=e[r](n.srcsetAttr);(t=n.customMedia[e[r]("data-media")||e[r]("media")])&&e.setAttribute("media",t),a&&e.setAttribute("srcset",a),t&&(o=e.parentNode,o.insertBefore(e.cloneNode(),e),o.removeChild(e))},K=function(){var e,t=[],n=function(){for(;t.length;)t.shift()();e=!1};return function(o){t.push(o),e||(e=!0,l(n))}}(),Q=function(e){var t,o,a,i,s,l,u,v=P.test(e.nodeName),b=v&&(e[r](n.sizesAttr)||e[r]("sizes")),z="auto"==b;(!z&&f||!v||!e.src&&!e.srcset||e.complete||g(e,n.errorClass))&&(z&&(u=e.offsetWidth),e._lazyRace=!0,x++,K(function(){e._lazyRace&&delete e._lazyRace,(s=_(e,"lazybeforeunveil")).defaultPrevented||(b&&(z?(A.updateElem(e,!0,u),p(e,n.autosizesClass)):e.setAttribute("sizes",b)),o=e[r](n.srcsetAttr),t=e[r](n.srcAttr),v&&(a=e.parentNode,i=a&&c.test(a.nodeName||"")),l=s.detail.firesLoad||"src"in e&&(o||t||i),s={target:e},l&&(h(e,G,!0),clearTimeout(E),E=d(G,2500),p(e,n.loadingClass),h(e,U,!0)),i&&m.call(a.getElementsByTagName("source"),J),o?e.setAttribute("srcset",o):t&&!i&&(k.test(e.nodeName)?Y(e,t):e.src=t),(o||i)&&y(e,{src:t})),w(e,n.lazyClass),(!l||e.complete)&&(l?G(s):x--,U(s))}))},V=function(){if(!f){if(Date.now()-C<9 ...
#                             window.__mwads.slots['ad-search-sponsor'] = googletag.defineSlot('/2/marketwatch.com/sponsor_search', [[1,2],['fluid']], 'ad-search-sponsor')
#                                 .defineSizeMapping([])
#                                 .addService(googletag.pubads())
#                                     .setTargeting('adlocation', ['nativesearch'])
#                                     .setTargeting('alert', ['volatility075','red'])
#                             ;googletag.display('ad-search-sponsor');
#                         });ListingsColumnsAuthorsTopicsNo results foundPrivateVideo Center×(function(a,b,c,d){
#                 a='//tags.tiqcdn.com/utag/wsjdn/marketwatch/prod/utag.js';b=document;c='script';d=b.createElement(c);d.src=a;d.type='text/java'+c;d.async=true;a=b.getElementsByTagName(c)[0];a.parentNode.insertBefore(d,a);})();

# %%
tokens = [t for t in text.split()]
print(tokens)
# Out:
# ['MarketWatch:', 'Stock', 'Market', 'News', '-', 'Financial', 'News', '-', 'MarketWatch@import', 'url("https://fonts.googleapis.com/css?family=Lato:700&text=amp1234567890.%25%24%E2%82%AC%C2%A3%C2%A5%C2%A2");[class*="', 'icon--"]:before,[class^=icon--]:before{font-family:icons!important;speak:none;font-style:normal;font-weight:400;font-variant:normal;text-transform:none;line-height:1;min-width:18px;display:inline-block;content:"";-webkit-font-smoothing:antialiased;-moz-osx-font-smoothing:grayscale}.slide-down{-webkit-animation-name:a;animation-name:a;-webkit-animation-duration:.5s;animation-duration:.5s;-webkit-animation-timing-function:ease;animation-timing-function:ease;visibility:visible!important}@-webkit-keyframes', 'a{0%{-webkit-transform:translateY(-100%);transform:translateY(-100%)}to{-webkit-transform:translateY(0);transform:translateY(0)}}@keyframes', 'a{0%{-webkit-transform:translateY(-100%);transform:translateY(-100%)}to{-webkit-transform:translateY(0);transform:translateY(0)}}@-webkit-keyframes', 'b{0%{opacity:0}50%{opacity:1}to{opacity:0}}@keyframes', 'b{0%{opacity:0}50%{opacity:1}to{opacity:0}}.font--smallest{font-size:.64286rem}.font--smaller{font-size:.71429rem}.font--small{font-size:.85714rem}.font--bold{font-weight:700}a,abbr,acronym,address,applet,article,aside,audio,b,big,blockquote,body,canvas,caption,center,cite,code,dd,del,details,dfn,div,dl,dt,em,embed,fieldset,figcaption,figure,footer,form,h1,h2,h3,h4,h5,h6,header,hgroup,html,i,iframe,img,ins,kbd,label,legend,li,mark,menu,nav,object,ol,output,p,pre,q,ruby,s,samp,section,small,span,strike,strong,sub,summary,sup,table,tbody,td,tfoot,th,thead,time,tr,tt,u,ul,var,video{margin:0;padding:0;border:0;font-size:100%;font:inherit;vertical-align:baseline}article,aside,details,figcaption,figure,footer,header,hgroup,menu,nav,section{display:block}body{line-height:1.375}ol,ul{list-style:none}blockquote,q{quotes:none}blockquote:after,blockquote:before,q:after,q:before{content:"";content:none}table{border-collapse:collapse;border-spacing:0}body,html{margin:0;overflow-x:hidden;padding:0}html{box-sizing:border-box;font-size:14px;line-height:1.375;-webkit-backface-visibility:hidden;backface-visibility:hidden}*,:after,:before{box-sizing:inherit;-webkit-tap-highlight-color:rgba(0,0,0,0)}body{margin:0;font-family:Lato,sans-serif;font-size:1rem;color:#202020}body>iframe{display:none}h1,h2,h3,h4,h5,h6{margin:0;font-weight:700}a{color:inherit;text-decoration:none}em{font-style:italic}strong{font-weight:700}button:hover,select:hover{cursor:pointer}button,input,select{border:none;border-radius:0;background:none;-webkit-appearance:none;-moz-appearance:none;appearance:none}button:focus,input:focus,select:focus{outline:none}option{background:#fff;color:#202020}img{display:block;width:100%}ul{list-style-type:none}li,ul{margin:0;padding:0}sub,sup{font-size:75%;line-height:0;position:relative;vertical-align:baseline}sup{top:-.5em}sub{bottom:-.25em}body:after,template{display:none}body:after{content:"ExtraLarge"}@media', '(max-width:1295px){body:after{content:"Large"}}@media', '(max-width:975px){body:after{content:"Medium"}}@media', '(max-width:655px){body:after{content:"Small"}}body{padding-top:50px}body.has-bulletin{padding-top:90px}body.has-bulletins{padding-top:130px}.container{display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-flow:row', 'wrap;-ms-flex-flow:row', 'wrap;flex-flow:row', 'wrap;-webkit-align-items:flex-start;-ms-flex-align:start;align-items:flex-start;margin:0', 'auto;max-width:1280px;width:100%}.container', '.region--primary{max-width:960px}.container', '.region--aside{max-width:320px;-webkit-align-self:stretch;-ms-flex-item-align:stretch;-ms-grid-row-align:stretch;align-self:stretch}.region{-webkit-align-content:flex-start;-ms-flex-line-pack:start;align-content:flex-start}.component,.region{position:relative;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-flow:row', 'wrap;-ms-flex-flow:row', 'wrap;flex-flow:row', 'wrap;-webkit-just ...

# %%
from nltk.corpus import stopwords
sr= stopwords.words('english')
clean_tokens = tokens[:]
for token in tokens:
    if token in stopwords.words('english'):
        
        clean_tokens.remove(token)
freq = nltk.FreqDist(clean_tokens)
for key,val in freq.items():
    print(str(key) + ':' + str(val))
freq.plot(20, cumulative=False)
# Out:
# MarketWatch::1
# Stock:5
# Market:1
# News:3
# -:41
# Financial:1
# MarketWatch@import:1
# url("https://fonts.googleapis.com/css?family=Lato:700&text=amp1234567890.%25%24%E2%82%AC%C2%A3%C2%A5%C2%A2");[class*=":1
# icon--"]:before,[class^=icon--]:before{font-family:icons!important;speak:none;font-style:normal;font-weight:400;font-variant:normal;text-transform:none;line-height:1;min-width:18px;display:inline-block;content:"";-webkit-font-smoothing:antialiased;-moz-osx-font-smoothing:grayscale}.slide-down{-webkit-animation-name:a;animation-name:a;-webkit-animation-duration:.5s;animation-duration:.5s;-webkit-animation-timing-function:ease;animation-timing-function:ease;visibility:visible!important}@-webkit-keyframes:1
# a{0%{-webkit-transform:translateY(-100%);transform:translateY(-100%)}to{-webkit-transform:translateY(0);transform:translateY(0)}}@keyframes:1
# a{0%{-webkit-transform:translateY(-100%);transform:translateY(-100%)}to{-webkit-transform:translateY(0);transform:translateY(0)}}@-webkit-keyframes:1
# b{0%{opacity:0}50%{opacity:1}to{opacity:0}}@keyframes:1
# b{0%{opacity:0}50%{opacity:1}to{opacity:0}}.font--smallest{font-size:.64286rem}.font--smaller{font-size:.71429rem}.font--small{font-size:.85714rem}.font--bold{font-weight:700}a,abbr,acronym,address,applet,article,aside,audio,b,big,blockquote,body,canvas,caption,center,cite,code,dd,del,details,dfn,div,dl,dt,em,embed,fieldset,figcaption,figure,footer,form,h1,h2,h3,h4,h5,h6,header,hgroup,html,i,iframe,img,ins,kbd,label,legend,li,mark,menu,nav,object,ol,output,p,pre,q,ruby,s,samp,section,small,span,strike,strong,sub,summary,sup,table,tbody,td,tfoot,th,thead,time,tr,tt,u,ul,var,video{margin:0;padding:0;border:0;font-size:100%;font:inherit;vertical-align:baseline}article,aside,details,figcaption,figure,footer,header,hgroup,menu,nav,section{display:block}body{line-height:1.375}ol,ul{list-style:none}blockquote,q{quotes:none}blockquote:after,blockquote:before,q:after,q:before{content:"";content:none}table{border-collapse:collapse;border-spacing:0}body,html{margin:0;overflow-x:hidden;padding:0}html{box-sizing:border-box;font-size:14px;line-height:1.375;-webkit-backface-visibility:hidden;backface-visibility:hidden}*,:after,:before{box-sizing:inherit;-webkit-tap-highlight-color:rgba(0,0,0,0)}body{margin:0;font-family:Lato,sans-serif;font-size:1rem;color:#202020}body>iframe{display:none}h1,h2,h3,h4,h5,h6{margin:0;font-weight:700}a{color:inherit;text-decoration:none}em{font-style:italic}strong{font-weight:700}button:hover,select:hover{cursor:pointer}button,input,select{border:none;border-radius:0;background:none;-webkit-appearance:none;-moz-appearance:none;appearance:none}button:focus,input:focus,select:focus{outline:none}option{background:#fff;color:#202020}img{display:block;width:100%}ul{list-style-type:none}li,ul{margin:0;padding:0}sub,sup{font-size:75%;line-height:0;position:relative;vertical-align:baseline}sup{top:-.5em}sub{bottom:-.25em}body:after,template{display:none}body:after{content:"ExtraLarge"}@media:1
# (max-width:1295px){body:after{content:"Large"}}@media:1
# (max-width:975px){body:after{content:"Medium"}}@media:1
# (max-width:655px){body:after{content:"Small"}}body{padding-top:50px}body.has-bulletin{padding-top:90px}body.has-bulletins{padding-top:130px}.container{display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-flow:row:1
# wrap;-ms-flex-flow:row:10
# wrap;flex-flow:row:10
# wrap;-webkit-align-items:flex-start;-ms-flex-align:start;align-items:flex-start;margin:0:1
# auto;max-width:1280px;width:100%}.container:1
# .region--primary{max-width:960px}.container:1
# .region--aside{max-width:320px;-webkit-align-self:stretch;-ms-flex-item-align:stretch;-ms-grid-row-align:stretch;align-self:stretch}.region{-webkit-align-content:flex-start;-ms-flex-line-pack:start;align-content:flex-start}.component,.region{position:relative;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-flow:row:1
# wrap;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;width:100%}.component{margin-bottom:20px}.component:1
# .component,.component.no-margin{margin-bottom:0}.column{position:relative;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-flow:row:1
# wrap;-webkit-align-items:flex-start;-ms-flex-align:start;align-items:flex-start;-webkit-align-content:flex-start;-ms-flex-line-pack:start;align-content:flex-start;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;padding:0:1
# 10px;width:100%}.element,.group,.list{position:relative;margin-bottom:20px;width:100%}.element:1
# .element,.element:2
# .group,.element:2
# .list,.group:2
# .element,.group:2
# .group,.group:2
# .list,.list:2
# .element,.list:2
# .group,.list:2
# .list{margin-bottom:0}.element:1
# .tab__pane:9
# .list{margin-bottom:20px}.fixed{position:fixed;left:50%;-webkit-transform:translateX(-50%);transform:translateX(-50%);z-index:9}@media:1
# (max-width:1295px){.container{max-width:960px}.container:1
# .region--primary{max-width:640px}.container:1
# .region--aside{max-width:320px}}@media:1
# (max-width:975px){.container,.container:1
# .region{max-width:640px}}@media:1
# (max-width:655px){.container,.region{max-width:100%}}.full-width{position:relative}.full-width:after,.full-width:before{content:"";position:absolute;top:0;bottom:0;z-index:-1;width:50vw}.full-width:before{left:50%}.full-width:after{right:50%}.is-loading:before{content:"Loading...";position:absolute;margin:auto;color:#939393;font-size:.64286rem;top:calc(50%:1
# 4px);left:calc(50%:2
# 18px)}.hidden{display:none!important}.container--lightbox{opacity:0;visibility:hidden}.element__title{display:inline-block;padding-right:10px;text-transform:uppercase;font-size:.85714rem;font-weight:700;color:#3677a8;background:#fff}.paragraph{font-size:1rem;line-height:1.5;margin-bottom:.8em}.negative,.negative+.character,.negative:1
# .character{color:#b51a28}.negative:1
# .icon{position:relative;display:inline-block;width:10px;height:10px}.negative:1
# .icon:before{content:"";position:absolute;top:calc(50%:2
# 2px);width:0;height:0;border-style:solid;border-width:5px:1
# 4px;border-color:#b51a28:1
# transparent:7
# transparent}.positive,.positive+.character,.positive:1
# .character{color:#3e9e3e}.positive:1
# .icon{position:relative;display:inline-block;width:10px;height:10px}.positive:1
# 2px);width:0;height:0;border-style:solid;border-width:0:1
# 4px:4
# 5px;border-color:transparent:2
# #3e9e3e}.neutral,.neutral+.character,.neutral:1
# .character,.neutral:1
# .icon{color:#939393}.ignore-color.negative,.ignore-color:1
# .negative,.ignore-color.neutral,.ignore-color:1
# .neutral,.ignore-color.positive,.ignore-color:1
# .positive,.negative:1
# .ignore-color,.neutral:1
# .ignore-color,.positive:1
# .ignore-color{color:inherit}.citation{display:inline-block;font-size:.71429rem;line-height:1.375;margin-right:5px}.citation__number{padding-right:2px;font-weight:400}.noscroll{overflow:hidden}body.noscroll{padding-right:15px}.toggle{display:none}.j-scrollElement,.j-scrollViewport{position:relative}.download__data{margin-bottom:20px}.download__data.w50{margin-bottom:0}.download__data:1
# a{color:#939393;font-size:.71429rem;transition:color:1
# .2s:7
# ease-in-out}.download__data:1
# a:after{content:"";display:inline-block;width:10px;height:10px;margin-left:3px;background-image:url(../images/download.svg);background-repeat:no-repeat;background-size:auto:1
# 100%}.download__data:1
# a:hover{color:#2e2e2e}@media:1
# (-ms-high-contrast:active),(-ms-high-contrast:none){.download__data{display:none}}@media:1
# (min-width:655px){.transactions:1
# .download__data{position:absolute;right:0;top:-35px}}.region--full>.component.ad:1
# .is-loading>div{min-height:90px}.component--aside:1
# .is-loading>div{min-height:250px}[is=mw-sticky]{-webkit-align-self:flex-start;-ms-flex-item-align:start;align-self:flex-start;padding:0:1
# 10px}[is=mw-sticky]:1
# .column{padding:0}.element--ad{margin-bottom:0;border:none!important;box-shadow:none!important}.element--ad>div{position:relative;margin-bottom:34px;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center}.element--ad>div:after{content:"Advertisement";position:absolute;top:calc(100%:1
# +:6
# 5px);left:0;right:0;text-align:center;font-size:.64286rem;letter-spacing:.05em;color:#939393;white-space:nowrap}.is-native:1
# .element--ad>div:after{display:none}.region--aside:1
# .element--ad>div{width:300px;min-height:250px}.container--advertisement:1
# .element--ad>div{min-width:728px;min-height:90px}.element--ad.is-loading:before{display:none}.element--ad.is-loading>div{background:hsla(0,0%,6%,.05)}.background--dark:1
# .element--ad.is-loading>div{background:hsla(0,0%,100%,.1)}.background--dark:1
# .element--ad.is-loading>div:before{border-color:hsla(0,0%,100%,.15);border-top-color:hsla(0,0%,100%,.3)}.element--ad.is-loading>div:before{content:"Loading...";position:absolute;margin:auto;color:#939393;font-size:.64286rem;top:calc(50%:1
# 18px)}.page--home:1
# .container--advertisement:1
# .element{width:auto;margin:0:1
# auto}@media:1
# (max-width:1295px){.container--advertisement:1
# .column{padding:0}}@media:1
# (max-width:975px){.region--aside:1
# .sticky__innards{width:100%}.region--aside:1
# .element--ad{margin:0:1
# auto;max-width:300px}}.btn--lighten{background:hsla(0,0%,100%,.1);color:#fff}.btn--lighten:hover{background:hsla(0,0%,100%,.15)}.horizontal{display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-flow:row:1
# nowrap;-ms-flex-flow:row:21
# nowrap;flex-flow:row:21
# nowrap}.temporary-banner:1
# .element--message{position:relative;background:#f3f3f3;width:100%;box-shadow:0:1
# 0:194
# 1px:11
# #e1e1e1;margin:0;padding:15px:1
# 20px;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-flow:row:1
# nowrap;height:auto;border:none;text-align:left}.temporary-banner:1
# .element--message:22
# .message__title{font-size:1.28571rem;font-weight:700;margin-bottom:5px}.temporary-banner:1
# .btn--icon{position:absolute;top:0;right:0;font-size:1.71429rem;opacity:.3;padding:10px;height:34px;width:34px;line-height:14px;transition:opacity:1
# .1s:1
# ease-in-out}.temporary-banner:1
# .btn--icon:hover{opacity:.6;cursor:pointer}.temporary-banner:1
# .group--buttons,.temporary-banner:1
# .message__text{-webkit-flex:0:1
# 1:24
# auto;-ms-flex:0:3
# auto;flex:0:3
# auto}.temporary-banner:1
# .message__text{-webkit-flex:1;-ms-flex:1;flex:1;margin-right:20px;-webkit-align-self:center;-ms-flex-item-align:center;-ms-grid-row-align:center;align-self:center}.temporary-banner:1
# .message__text:4
# .primary{font:800:1
# 1.28571rem:1
# Muli,sans-serif;color:#202020}.temporary-banner:1
# .secondary{font:400:1
# .92857rem/1.375:1
# Lato,sans-serif;color:#6a6a6a}.temporary-banner:1
# .group--buttons{display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-flow:row:1
# nowrap;-webkit-align-self:flex-end;-ms-flex-item-align:end;align-self:flex-end;margin:0;width:auto}.temporary-banner:1
# .group--buttons:8
# .btn{font:400:1
# .85714rem/.9:1
# Lato,sans-serif;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;-webkit-align-items:center;-ms-flex-align:center;align-items:center;min-width:160px;text-transform:none;letter-spacing:.05em;white-space:nowrap}.temporary-banner:1
# .btn.btn--outline{font-weight:800}.temporary-banner:1
# .btn+.btn{margin-left:2px}.temporary-banner:1
# .link{color:#3677a8;text-decoration:underline;white-space:nowrap}.temporary-banner:1
# .link:hover{text-decoration:none}.page--vse.welcome:1
# .container--banner{display:none!important}.page--vse:1
# .container--banner{position:relative;background:#000;padding-top:20px}.page--vse:1
# .container--banner:after,.page--vse:1
# .container--banner:before{content:"";position:absolute;top:0;bottom:0;z-index:-1;background:#000;width:50vw}.page--vse:1
# .container--banner:before{left:50%}.page--vse:1
# .container--banner:after{right:50%}.page--vse:1
# .container--banner:2
# .group{margin:0}.page--vse:1
# .group:3
# .item--headline{box-shadow:inset:1
# 2px:4
# #000}.container--banner:1
# .element--message{box-shadow:0:1
# #e1e1e1;padding:15px:1
# 0}.container--banner:1
# .element--message:after,.container--banner:1
# .element--message:before{content:"";position:absolute;top:0;bottom:0;z-index:-1;width:50vw;background:#f3f3f3;box-shadow:0:1
# #e1e1e1}.container--banner:1
# .element--message:before{left:50%}.container--banner:1
# .element--message:after{right:50%}.container--banner:1
# .btn--icon{right:15px}.container--banner:1
# .group--show{overflow:hidden;color:#fff;border-radius:2px;background-color:#3677a8}.container--banner:1
# .group--show:36
# .show__item{padding:20px;position:relative}@media:1
# (-ms-high-contrast:active),(-ms-high-contrast:none){.container--banner:4
# .show__item{-webkit-flex:1;-ms-flex:1;flex:1}}.container--banner:1
# .item--thumbnail{padding:0;display:block;width:100%;max-width:-webkit-max-content;max-width:-moz-max-content;max-width:max-content;max-height:101px;min-width:180px;max-width:180px}.container--banner:1
# .item--thumbnail:1
# .img{height:100%;width:180px}@media:1
# .item--thumbnail{-webkit-flex:1:2
# 180px;-ms-flex:1:3
# 180px;flex:1:3
# 180px;max-width:180px}}@supports:1
# (-ms-ime-align:auto){.container--banner:2
# 180px;max-width:180px}}.container--banner:2
# .video--show{height:100%;min-width:-webkit-fit-content}@media:1
# (min-resolution:0.001dpcm){.container--banner:1
# .video--show{display:block}}.container--banner:1
# .item--headline{display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-flow:column;-ms-flex-flow:column;flex-flow:column;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;-webkit-align-items:flex-start;-ms-flex-align:start;align-items:flex-start;box-shadow:inset:1
# #fff}.container--banner:1
# .show__status{position:relative;margin-bottom:5px;text-transform:uppercase;font-size:.85714rem}.container--banner:1
# .show__status:after{content:"";position:absolute;top:calc(50%:1
# 2.5px);width:5px;height:5px;display:inline-block;border-radius:50%;margin-left:5px;background:#d69628;-webkit-animation:b:1
# 3s:4
# ease-in-out:4
# infinite;animation:b:2
# infinite}.container--banner:1
# .show__headline{line-height:1.375;font-size:1.14286rem}@media:1
# .show__headline{width:100%}}@supports:1
# .show__headline{width:100%}}.container--banner:1
# .bar{margin:0:1
# 10px}.container--banner:3
# .market__open{font-weight:400;color:hsla(0,0%,100%,.75)}.container--banner:1
# .open__countdown{font-weight:700;color:#fff}.container--banner:1
# .item--sponsor{margin-left:auto;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-ms-flex-align:center;align-items:center;-webkit-justify-content:flex-end;-ms-flex-pack:end;justify-content:flex-end}@media:1
# .item--sponsor{-webkit-flex:1:2
# .item--sponsor:4
# .element--ad>div{margin:0}.container--banner:1
# .element--ad>div:after,.container--banner:1
# .element--ad>div:before{display:none}.container--banner:1
# .element--ad.is-loading>div:before{top:calc(50%:1
# 5px)}.container--banner:1
# .item--logo{margin-left:auto;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-justify-content:flex-end;-ms-flex-pack:end;justify-content:flex-end;-webkit-align-items:center;-ms-flex-align:center;align-items:center;max-width:240px}.container--banner:1
# .item--logo:1
# .img{max-width:200px}.container--banner:1
# .sponsor__label{opacity:.75;font-size:.71429rem;margin-bottom:5px;text-transform:uppercase}.container--banner:1
# .sponsor__ad{height:31px;width:140px;margin-left:10px}@media:1
# (max-width:975px){.container--banner:1
# .group--show{padding:20px}.container--banner:1
# .show__item{padding:0}.container--banner:1
# .element--message{-webkit-flex-flow:row:1
# wrap}.container--banner:1
# .message__text{text-align:center;margin:0;-webkit-flex:1:1
# 100%;-ms-flex:1:2
# 100%;flex:1:2
# 100%}.container--banner:1
# .group--buttons{margin-top:10px;-webkit-align-self:center;-ms-flex-item-align:center;-ms-grid-row-align:center;align-self:center}.container--banner:1
# .item--thumbnail{display:none}.container--banner:1
# .item--headline{box-shadow:none}.market__open{display:block;width:100%}.market__open:1
# .bar{display:none}}@media:1
# (max-width:655px){.container--banner:1
# .group--show{padding:10px}.container--banner:1
# .show__status{margin:0}.container--banner:1
# .market__open{font-size:.92857rem;margin-top:5px}.container--banner:1
# .element--message{margin-bottom:0;padding:15px:1
# .primary{font-size:1.14286rem}.container--banner:1
# .secondary{font-size:.92857rem}.container--banner:1
# .group--buttons{width:100%}.container--banner:1
# .btn{-webkit-flex:1;-ms-flex:1;flex:1;min-width:0}.container--banner:1
# .m-show{display:inline}.container--banner{padding:0}.container--banner:1
# .element--message{padding:15px:1
# .item--logo{display:none}.container--banner:1
# .sponsor__ad{height:20px;width:80px}}@media:1
# (max-width:655px):1
# (-ms-high-contrast:active),(max-width:655px):1
# (-ms-high-contrast:none){.container--banner:1
# 80px;-ms-flex:1:1
# 80px;flex:1:1
# 80px;max-width:80px}}.container--masthead{margin-bottom:20px}.container--masthead:1
# .fixed{top:0;max-width:1280px;height:50px}.masthead{display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-flow:row:1
# nowrap;-webkit-align-items:center;-ms-flex-align:center;align-items:center}.masthead,.masthead:after,.masthead:before{background:#2e2e2e}.masthead:1
# .btn--menu,.masthead:1
# .btn--search{-webkit-flex:0:1
# 50px;-ms-flex:0:1
# 50px;flex:0:1
# 50px;height:50px;padding:0}.masthead:1
# .btn--menu{background:#3677a8}.masthead:1
# .btn--search{position:relative}.masthead:1
# .btn--search:before{content:"";position:absolute;top:17px;left:17px;border-radius:50%;width:14px;height:14px;border:2px:1
# solid:90
# #fff;display:block}.masthead:1
# .btn--search:after{content:"";position:absolute;left:27px;top:29px;width:7px;height:2px;display:block;background:#fff;-webkit-transform:rotate(45deg);transform:rotate(45deg);border-radius:1px}.masthead:1
# .logo{-webkit-flex:0:1
# 170px;-ms-flex:0:1
# 170px;flex:0:1
# 170px;width:170px;margin-left:15px;margin-right:0}.masthead:1
# .logo:2
# svg{max-height:50px}.masthead:1
# a{display:block}.masthead:1
# .top-menu{margin:0;padding:10px:1
# 0;max-width:185px;width:auto}.masthead:1
# .top-menu:1
# .btn{border-radius:2px;line-height:30px;display:inline-block;padding:0:1
# 10px}.btn--menu{position:relative;background:#3677a8}.btn--menu:1
# .icon{position:absolute;top:calc(50%:4
# 1px);left:calc(50%:2
# 8px);display:block;width:16px;height:2px;background:#fff}.btn--menu:1
# .icon:after,.btn--menu:1
# .icon:before{content:"";position:absolute;left:0;right:0;height:2px;background:#fff}.btn--menu:1
# .icon:before{top:-5px}.btn--menu:1
# .icon:after{bottom:-5px}#nav__menu{opacity:0;transition:opacity:1
# .3s:1
# ease-in-out}#nav__menu.fade-in{opacity:1}.list--menu{display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-flow:row:1
# wrap;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;-webkit-flex-shrink:1;-ms-flex-negative:1;flex-shrink:1;overflow:hidden;width:auto;height:50px;margin:0:1
# auto;padding:0:1
# 10px}.list--menu.overlfow-visible{overflow:visible}.list--menu:1
# .menu__item{font:400:1
# 1rem/50px:1
# Muli,sans-serif;height:50px;margin:0:1
# 7.5px;color:#fff;border-bottom:5px:1
# #2e2e2e;position:relative}.list--menu:1
# .menu__item.is-active{border-bottom-color:#378c37}.list--menu:1
# .menu__item.is-active[data-section*=barrons]{border-bottom-color:#3677a8}.list--menu:1
# .menu__item:hover:not(.is-active){border-bottom-color:#6a6a6a}.list--menu:1
# [href*=latest-news]{position:relative}.list--menu:1
# [href*=latest-news]:before{content:"";position:absolute;top:calc(50%:1
# 2.5px);left:-10px;width:5px;height:5px;display:inline-block;border-radius:50%;margin-right:5px;background:#4db74d;-webkit-animation:b:1
# infinite}.menu__item.item--more{color:#fff;display:-webkit-flex;display:-ms-flexbox;display:flex}.menu__item.item--more:1
# .more__btn{color:#fff;padding:0;font:inherit;height:50px}.menu__item.item--more:1
# .more__btn:after{content:"\e908";font-family:icons;font-size:.64286rem;margin-left:5px}.menu__item.item--more:1
# .more__dropdown{position:absolute;background:#484848;padding:10px:1
# 0;top:100%;left:-20px;display:none;z-index:9}.menu__item.item--more:1
# .more__dropdown.show{display:block}.menu__item.item--more:1
# .more__dropdown:2
# a{white-space:nowrap;color:#fff;display:block;padding:10px:1
# 20px:2
# 10px:8
# 15px;border-left:5px:1
# hsla(0,0%,100%,.001);line-height:1}.menu__item.item--more:1
# a:hover{border-left:5px:1
# #6a6a6a}.nav{display:none}.profile{font:400:1
# 1rem/1.375:5
# Muli,sans-serif;margin-right:10px;white-space:nowrap}.profile:1
# .btn{text-transform:none;height:auto}.profile:1
# .divider{margin:0:1
# 5px;font-size:.9em}.account-links{display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-flow:row:1
# nowrap;color:#939393;-webkit-align-items:center;-ms-flex-align:center;align-items:center}@media:1
# (max-width:1295px){.container--masthead:1
# .region{max-width:960px}.container--masthead:1
# .list--menu:1
# .menu__item{font-size:.92857rem;margin:0:1
# 5px}.container--masthead:1
# .profile{font-size:.92857rem}}@media:1
# (max-width:975px){.container--masthead:1
# .region{max-width:640px}.container--masthead:1
# .logo{margin-right:auto}.container--masthead:1
# .list--menu{display:none}}@media:1
# (max-width:655px){.container--masthead.Expanded{margin-bottom:0}.container--masthead.Expanded:1
# .masthead-elements:1
# .column:after{border-bottom:none}.container--masthead:1
# .region{max-width:none}.container--masthead:1
# .masthead{padding:0;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between}.container--masthead:1
# .masthead:2
# .logo{margin:0}.container--masthead:1
# .top-menu,.profile{display:none}}.bulletins{position:absolute;top:50px;left:0;z-index:8;margin:0;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-flow:row:1
# nowrap;-webkit-align-items:center;-ms-flex-align:center;align-items:center}.bulletins,.bulletins:after,.bulletins:before{background:#3e9e3e}.bulletins:1
# .element--bulletins{display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-flow:column;-ms-flex-flow:column;flex-flow:column;margin:0}.bulletins:1
# .element--ad{margin:0;width:auto}.bulletins:1
# .element--ad>div{margin:0}.bulletins:1
# .element--ad.is-loading,.bulletins:1
# .element--ad>div:after{display:none}.bulletin{position:relative;padding:10px:1
# 40px:2
# 0;line-height:1.375;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-ms-flex-align:center;align-items:center;min-height:40px}.bulletin>.icon{position:absolute;top:calc(50%:1
# 15px);right:10px;display:block;width:30px;height:30px;color:#265e26;font-size:1.14286rem;text-align:center;line-height:32px}.bulletin>.icon:hover{color:#173a17;cursor:pointer}.bulletin:nth-child(2){border-top:1px:1
# hsla(0,0%,100%,.25)}.bulletin__headline{font:400:1
# Muli,sans-serif;color:#fff;display:inline;padding:0}.bulletin__headline:before{content:"BULLETIN";margin-right:10px;letter-spacing:.1em;font-weight:800}.bulletin__headline:1
# .link:hover{text-decoration:underline}.bulletin__headline:1
# .link:1
# .icon:before{content:"\e906";padding-left:5px;font-family:icons;font-size:.71429rem}.bulletin__headline:1
# .text{opacity:.75}@media:1
# (min-width:976px){.has-ad:1
# .element--bulletins{padding-right:15px}.has-ad:1
# .element--bulletins:2
# .bulletin{padding-right:30px}.has-ad:1
# .bulletin>.icon{right:-5px}}@media:1
# (max-width:975px){.bulletins:1
# .element--ad{display:none}.bulletin__headline{padding-left:0}.bulletin__headline:before{display:none}}@media:1
# (max-width:655px){.bulletins:1
# .bulletin{min-height:45px}.bulletins:1
# .bulletin>.icon{right:0}}.element--article{display:-webkit-flex;display:-ms-flexbox;display:flex}.element--article:1
# .article__summary{font:400:1
# Lato,sans-serif;padding-top:4px;background:#fff}.element--article:1
# .article__summary:empty{display:none}.element--article:1
# .article__headline:hover{color:#3677a8}.element--article:1
# .group--tickers{font:700:1
# .85714rem/1.125:1
# Lato,monospace;position:relative;display:-webkit-flex;display:-ms-flexbox;display:flex;height:18px;-webkit-flex-flow:row:1
# wrap;margin:6px:1
# 0;padding:6px:1
# 0;overflow:hidden}.element--article:1
# .group--tickers:before{content:"";position:absolute;top:0;left:0;width:15px;border-top:1px:1
# dotted:1
# #6a6a6a}.element--article:1
# .ticker{display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-flow:row:1
# nowrap;-webkit-align-items:center;-ms-flex-align:center;align-items:center;margin-right:5px;padding-right:10px}.element--article:1
# .ticker:hover:1
# .ticker__symbol{color:#b51a28}.element--article:2
# .ticker__symbol{color:#6a6a6a;font-weight:700}.element--article:1
# .ticker__change{padding:0:1
# .2em}.element--article:1
# .ticker__change+.icon{width:0;height:0;border-style:solid}.element--article:1
# .positive:hover:1
# .ticker__symbol{color:#3e9e3e}.element--article:1
# .negative:hover:1
# .neutral:2
# .icon{display:none}.element--article:1
# .neutral:hover:1
# .ticker__symbol{color:#939393}.element--article:1
# .list--bullets{margin:6px:1
# 5px;padding-left:10px}.element--article:1
# .list--bullets:6
# .bullet__item{font:400:1
# Lato,sans-serif;list-style-type:disc;margin-bottom:8px}.element--article:1
# .bullet__item:last-child{margin-bottom:0}.element--article:1
# .link{color:inherit}.element--article:1
# .link:hover{text-decoration:underline}.element--article:1
# .label--opinion{font-weight:700}.no-image:1
# .article__figure:193
# .figure__image{position:relative;background-size:100%}.no-image:1
# .figure__image:before{content:"\e932";font-family:icons;display:-webkit-flex;display:-ms-flexbox;display:flex;color:#fff;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;-webkit-align-items:center;-ms-flex-align:center;align-items:center;position:absolute;height:100%;width:100%;top:0;left:0;opacity:.9;margin:0;font-size:6rem;background-image:linear-gradient(to:9
# bottom:107
# right,#3e9e3e,#3677a8)}.no-image:1
# .figure__image[href*="barrons.com"]:before,.no-image:1
# .figure__image[href*="marketwatch.com/articles/"]:before,.no-image:1
# .figure__image[href^="/articles/"]:before{content:"\e934";background-image:linear-gradient(to:18
# right,#00529c,#1a2737)!important}.no-image:1
# .figure__image[href*="wsj.com/articles/"]:before{content:"\e933";background-image:linear-gradient(to:18
# right,#222,#666)!important}.no-image:1
# .figure__image[href*="mansionglobal.com"]:before{content:"\e967";background-image:linear-gradient(to:18
# right,#e9d29d,#958359)!important}.no-image:1
# .figure__image:hover:before{opacity:.75}.no-image:nth-of-type(2n):1
# .figure__image:before{background-image:linear-gradient(to:21
# right,#d69628,#b51a28)}.no-image:1
# .article__content:44
# .article__headline{position:relative}.no-image:1
# .article__summary{display:none}.article__figure{width:100%}.figure__image{position:relative;display:block;overflow:hidden;padding-bottom:56.25%}.figure__image:after,.figure__image:before{content:"";position:absolute;z-index:1;display:block;width:100%;height:100%;transition:opacity:1
# .4s:2
# ease-in-out}.figure__image:before{opacity:1;background:linear-gradient(0deg,rgba(0,0,0,.2):1
# 0,rgba(0,0,0,.1))}.figure__image:after{opacity:0;background:linear-gradient(180deg,rgba(0,0,0,.2):1
# 0,rgba(0,0,0,.1))}.figure__image:1
# img{position:absolute;top:0;width:100%}.figure__image:1
# 28px);left:calc(50%:1
# 28px);z-index:5;display:block;width:56px;height:56px;color:#fff;font-size:56px}.figure__image:hover:before{opacity:0}.figure__image:hover:after{opacity:1}.article__content{position:relative;z-index:2}.article__label{font:700:1
# .71429rem/1.75:43
# Lato,sans-serif;position:static;margin-bottom:2px;text-transform:uppercase;background-color:transparent;color:#3677a8;padding:0;letter-spacing:.025em;display:inline-block}.article__label.breaking,.article__label.live,.article__label.watch{color:#4db74d}.article__label.exclusive{color:#d69628}.article__label.corrected,.article__label.correction{color:#b51a28}.article__label.updated{color:#939393}.article__label.moneyish{color:#ff716c}.article__label.premium{color:#cb8900}.article__label.barrons{color:#00529c}.label--opinion{color:#3677a8}.article__details:1
# li{display:inline}.has-chart:1
# .article__figure{margin-bottom:10px}.has-chart:1
# .figure__image:after,.has-chart:1
# .figure__image:before{display:none}.has-chart:1
# .article__content{margin:0}.has-chart:1
# .article__headline{background:none;padding:0;width:100%}.no-shade:1
# .figure__image:after,.no-shade:1
# .figure__image:before{display:none}@media:1
# (max-width:655px){.element--article:1
# .bullet__item{font-size:1rem}}.header{position:relative;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-flow:column:1
# nowrap;-ms-flex-flow:column:1
# nowrap;flex-flow:column:1
# nowrap;width:100%;margin-bottom:10px;padding:0:1
# 10px}.column:1
# .header{padding-left:0;padding-right:0}.column:1
# .header:1
# .element--ad{right:0}.header:1
# .label{margin:0}.header:1
# .element--ad{position:absolute;top:3px;right:10px;z-index:3;width:140px}.header:1
# .element--ad>div:after,.header:1
# .element--ad>div:before{display:none}.header:1
# .element--ad.is-loaded>div{position:relative;width:140px;height:31px;margin-bottom:0;box-shadow:-5px:1
# #fff;background:#fff;min-height:0;min-width:0}.header:1
# .element--ad.is-loaded>div:before{display:none}.header:1
# .element--ad.is-loaded>div:after{content:"Presented:1
# By";display:block;position:absolute;top:-12px;width:140px;text-align:right;font-size:.64286rem;letter-spacing:.05em;color:#939393}.header:1
# .element--ad.is-loading>div{background:none;box-shadow:none}.header:1
# .element--ad.is-loading>div:after{display:none}.header--primary:1
# .title,.header--secondary:1
# .title{font:800:3
# .85714rem/.85:1
# Muli,sans-serif;position:relative;display:inline-block;letter-spacing:.025em;text-transform:uppercase;vertical-align:top;width:100%;margin-bottom:10px;line-height:1.375;overflow:hidden}.header--primary:1
# .title:before,.header--secondary:1
# .title:before{content:"";position:absolute;top:2px;left:0;width:100%;height:calc(100%:1
# 6px);background:repeating-linear-gradient(135deg,#e1e1e1,#e1e1e1:1
# 1px,transparent:1
# 2px,transparent:1
# 3px);background-size:4px:1
# 4px}.header--primary:1
# .title:4
# .label,.header--primary:1
# .link,.header--secondary:1
# .label,.header--secondary:1
# .link{background:#fff;padding-right:10px;position:relative;display:inline-block}.header--primary:1
# .paragraph,.header--secondary:1
# .paragraph{font:400:1
# Lato,sans-serif;color:#2e2e2e;margin:0}.header--primary.no-background:1
# .title:before,.header--secondary.no-background:1
# .title:before{display:none}.header--primary:1
# .title{font-size:2rem;color:#c3c3c3}.header--primary:1
# .title:before{top:8px;height:calc(100%:1
# 16px)}.header--secondary:1
# .title{color:#3677a8}.header--tertiary{margin-bottom:10px}.header--tertiary:1
# .title{font-size:.92857rem}.header--small{font:800:1
# .85714rem/1:2
# Muli,sans-serif;color:#2e2e2e;-webkit-align-items:flex-end;-ms-flex-align:end;align-items:flex-end}.header--small:1
# .primary{-webkit-align-self:flex-start;-ms-flex-item-align:start;align-self:flex-start}.header--small:1
# .secondary{color:#939393;font-size:.64286rem;letter-spacing:.05em;padding-left:5px;text-transform:uppercase}.masthead-elements:1
# .header--small{margin:0}.header--text{margin-bottom:10px}.header--text:1
# 1.14286rem/.9:1
# Muli,sans-serif;color:#2e2e2e}.header--page:1
# 1.71429rem/1.375:1
# Muli,sans-serif;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-flow:row:1
# nowrap;-webkit-align-items:center;-ms-flex-align:center;align-items:center;color:#3677a8}.header--page:1
# .image{-webkit-flex:none;-ms-flex:none;flex:none;width:auto;display:-webkit-flex;display:-ms-flexbox;display:flex;max-width:150px;max-height:50px;-webkit-align-items:center;-ms-flex-align:center;align-items:center;margin-right:10px;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center}.header--page:1
# .image:1
# img{width:auto;height:50px;max-width:100%;-o-object-fit:contain;object-fit:contain}.header--page:1
# .element--ad{top:calc(50%:2
# 15px);right:0;left:auto}.header--page:1
# .element--ad>div{background:#e1e1e1}.header--page:1
# .element--ad>div:after{top:calc(50%:1
# 5px);right:100%;left:auto;margin-right:5px;width:auto;line-height:1.125}@media:1
# (max-width:655px){.header:1
# .element--ad{width:80px}.header:1
# .element--ad.is-loaded>div{width:80px;height:20px}.header:1
# .element--ad.is-loaded>div:after{width:80px}.header--primary:1
# .title{font-size:1.71429rem}.header--primary:1
# .element--ad{top:0}.header--secondary:1
# .container__sponsor,.header--secondary:1
# .header__sponsor{top:-5px}.header--page:1
# .title{padding-right:90px;font-size:1.28571rem}.header--page:1
# 10px)}.header--page:1
# .element--ad>div:after{top:auto;right:0;bottom:110%;left:0;margin:0}}.header--secondary+.list--kv{margin-top:-15px}.list--breadcrumbs{font:600:1
# .78571rem/1.625:1
# Lato,sans-serif;border-bottom:1px:1
# #e1e1e1;color:#939393;padding-bottom:10px}.component--module.page-header:1
# .list--breadcrumbs,.page--quote:1
# .list--breadcrumbs{margin-bottom:0}.list--breadcrumbs:1
# .link{text-decoration:none}.list--breadcrumbs:1
# .link:hover{text-decoration:underline}.list--breadcrumbs:1
# .breadcrumb__item{position:relative;display:inline-block;margin:0:1
# 3px:1
# 0;white-space:nowrap}.list--breadcrumbs:1
# .breadcrumb__item:after{content:"\e902";display:inline-block;padding-left:3px;font-family:icons;font-size:.64286rem;color:#939393}.list--breadcrumbs:1
# .breadcrumb__item:last-child{color:#2e2e2e;font-weight:800}.list--breadcrumbs:1
# .breadcrumb__item:last-child:after{display:none}.list--breadcrumbs:1
# .breadcrumb__item:last-child:2
# .link{font-weight:800}.list--breadcrumbs:1
# .link:hover{text-decoration:none}@media:1
# (max-width:975px){.quote__nav{-webkit-flex-flow:column;-ms-flex-flow:column;flex-flow:column;-webkit-align-items:flex-start;-ms-flex-align:start;align-items:flex-start}}.masthead-elements{position:relative}.masthead-elements:1
# .column{display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-flow:row:1
# nowrap}.masthead-elements:1
# .column:after{content:"";position:absolute;left:10px;right:10px;bottom:0;border-bottom:1px:1
# #e1e1e1}.masthead-elements:3
# .element{margin:0}.masthead-elements:1
# .element--markets{-webkit-flex:1:1
# 530px;-ms-flex:1:3
# 530px;flex:1:3
# 530px}.masthead-elements:2
# .element--movers{-webkit-flex:0:2
# 200px;-ms-flex:0:2
# 200px;flex:0:2
# 200px}.masthead-elements:1
# .element--latestNews{-webkit-flex:1:1
# .element--latestNews:2
# .header--small{display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-flow:row:1
# nowrap;border-bottom:1px:1
# .header--small:3
# .btn--scroll{color:#3677a8}.masthead-elements:1
# .header--small{position:relative;padding:0:1
# 8px:3
# 5px;border-bottom:1px:1
# .header--small:before{content:"";position:absolute;top:0;bottom:0;border:3px:1
# #fff;right:100%}.masthead-elements:1
# .secondary{font-weight:600}@media:1
# (max-width:1295px){.masthead-elements:1
# .element--markets{-webkit-flex:0:1
# 460px;-ms-flex:0:1
# 460px;flex:0:1
# 460px}.masthead-elements:1
# .element--markets.mobile{display:none}.masthead-elements:1
# 180px;-ms-flex:0:1
# 180px;flex:0:1
# 180px}.masthead-elements:1
# .element--latestNews{-webkit-flex:0:1
# 300px;-ms-flex:0:1
# 300px;flex:0:1
# 300px}}@media:1
# (max-width:975px){.masthead-elements:1
# .element--markets{-webkit-flex:1;-ms-flex:1;flex:1;max-width:50%}.masthead-elements:1
# .element--markets:2
# .market__item:last-of-type,.masthead-elements:1
# .markets__chart,.masthead-elements:1
# .element--movers{display:none}.masthead-elements:1
# .element--latestNews{-webkit-flex:1;-ms-flex:1;flex:1;max-width:50%}}@media:1
# (max-width:655px){.masthead-elements{margin:0;padding:0}.masthead-elements:after{display:none}.masthead-elements:1
# .column{padding:0}.masthead-elements:1
# .element--markets{max-width:none}.masthead-elements:1
# .element--markets.mobile{display:-webkit-flex;display:-ms-flexbox;display:flex}.masthead-elements:1
# .element--latestNews,.masthead-elements:1
# .element--markets.desktop{display:none}}.max-markets{padding-top:10px}.element--markets{display:block;-webkit-flex:1:1
# 530px}.element--markets.mobile{display:none}.element--markets:1
# .list--markets{-webkit-flex:100%;-ms-flex:100%;flex:100%;margin:0;padding:0:1
# 5px;font-weight:700}.element--markets:1
# .list--markets:1
# [class*=icon--]{color:#4db74d;font-size:.71429rem}.element--markets:1
# .market__item{font:700:1
# Muli,sans-serif;background:transparent;box-shadow:none;margin-right:15px;color:#202020;padding:0;text-transform:none}.element--markets:1
# .market__item.is-selected{background:none;color:#3677a8;font-weight:800}.element--markets:1
# .market__item:last-child{width:auto;margin-left:auto;margin-right:0;height:12px}.element--markets:1
# .market__item:hover:not(:last-child){text-decoration:underline}.element--markets:1
# .dropdown{display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-ms-flex-align:center;align-items:center}.element--markets:1
# .dropdown:3
# .label{font-size:.64286rem;color:#939393;text-transform:uppercase}.element--markets:1
# .icon{position:relative;left:7px;z-index:-1;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;-webkit-align-items:center;-ms-flex-align:center;align-items:center;width:10px;height:10px}.element--markets:1
# .icon:before{content:"";width:0;height:0;border-style:solid;border-width:4px:1
# 0;border-color:#3677a8:1
# transparent}.element--markets:2
# .dropdown--markets{-webkit-appearance:none;-moz-appearance:none;appearance:none;background:none;border:none;color:#3677a8;font-size:.85714rem;font-weight:700;line-height:1.25;padding-left:10px;width:auto}.element--markets:1
# .dropdown--markets:hover{cursor:pointer;background:none}.element--markets:1
# .dropdown--markets::-ms-expand{display:none}.element--markets:1
# .markets--desktop{display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-flow:row:1
# nowrap}.element--markets:1
# .markets--desktop:2
# .markets__table{-webkit-flex:1;-ms-flex:1;flex:1}.element--markets:1
# .markets__chart{-webkit-flex:0:1
# 204px;-ms-flex:0:1
# 204px;flex:0:1
# 204px}.element--markets:1
# .table{-webkit-flex:1;-ms-flex:1;flex:1;border-left:1px:1
# #e1e1e1;width:100%}.element--markets:1
# .table:4
# .indicator{border-left:3px:1
# transparent;padding-right:5px}.element--markets:1
# .positive:2
# .indicator{border-color:#3e9e3e}.element--markets:1
# .negative:2
# .indicator{border-color:#b51a28}.element--markets:1
# .indicator{border-color:#939393}.element--markets:1
# .table__row{border:none;border-top:1px:1
# #e1e1e1}.element--markets:3
# .table__row.is-active,.element--markets:1
# .table__row:hover{background:#f2f6fa;box-shadow:inset:1
# -1px:23
# #fff,inset:3
# #fff;cursor:pointer}.element--markets:1
# .table__row[is-closed]:1
# .table__cell:5
# .indicator{border-color:#939393!important}.element--markets:1
# .table__cell{font:700:1
# .85714rem/1.375:5
# Lato,monospace;position:relative;padding:5px:1
# 5px:4
# 0;white-space:nowrap}.element--markets:1
# 2.5px);right:8px;width:0;height:0;border-style:solid;opacity:1}.element--markets:1
# .icon:before{display:none}.element--markets:1
# .icon{border-width:0:1
# #3e9e3e}.element--markets:1
# .icon{border-width:5px:1
# 0;border-color:#b51a28:1
# .table__cell:first-child{padding:1px:1
# 8px;width:13px}.element--markets:1
# .table__cell:last-child{padding:5px:1
# 10px}.element--markets:1
# .table__cell:nth-child(2){font-family:Muli,sans-serif;font-weight:800;text-align:left;letter-spacing:.025em}.element--markets:1
# .table__cell.ignore-color{color:#2e2e2e}.element--markets:1
# .markets__chart{position:relative;z-index:1;height:162px;background:#f3f3f3;border-left:1px:1
# .markets__chart:3
# .mike-tip-bullet,.element--markets:1
# .mike-tip-date,.element--markets:1
# .mike-tip-label{display:none}.element--markets:1
# .markets__chart.is-loading{box-shadow:inset:1
# #e1e1e1}.min-markets{background-color:#fff;transition:padding:1
# ease-in-out;position:relative;background:#fff}.min-markets:after,.min-markets:before{content:"";position:absolute;top:0;bottom:0;z-index:-1;background:#fff;width:50vw}.min-markets:before{left:50%}.min-markets:after{right:50%}.container--masthead:1
# .min-markets.column{padding:13px:1
# 14px}.container--masthead:1
# .min-markets.column:after{top:0;right:50%;left:auto}.min-markets:after,.min-markets:before{height:calc(100%:1
# 1px);border-bottom:1px:1
# #e1e1e1}.min-markets:1
# .group{width:100%;margin-bottom:0;position:relative}.markets__select{-webkit-flex:0:1
# auto;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-ms-flex-align:center;align-items:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center}.markets__select:before{content:"";width:0;height:0;border-left:3px:1
# transparent;border-right:3px:1
# transparent;border-top:3px:1
# #939393;top:calc(50%:1
# 1px);display:inline-block;margin-right:-10px}.markets__select:1
# .dropdown{width:auto;padding:0:1
# 15px;background:transparent;color:#939393;font-size:.85714rem;font-weight:600;border-right:1px:1
# #e1e1e1;-webkit-appearance:none}.markets__list{margin:auto;-webkit-align-items:center;-ms-flex-align:center;align-items:center;max-width:960px;min-width:0}.markets__list:after{content:"";position:absolute;height:100%;width:25px;right:0;top:0;background-image:linear-gradient(90deg,hsla(0,0%,100%,.001),#fff)}.markets__list::-webkit-scrollbar{display:none}.markets__list,.markets__list:1
# .list__item{-webkit-flex:auto;-ms-flex:auto;flex:auto}.markets__list:1
# .list__item{font-weight:600;font-size:.85714rem;text-align:center;padding:0:1
# 10px;white-space:nowrap;line-height:1.375}.markets__list:1
# .list__item:1
# .label{margin-right:5px}.markets__list:1
# .value{color:#3e9e3e}.markets__list:1
# .value.negative{color:#b51a28}.markets__data{-webkit-flex:auto;-ms-flex:auto;flex:auto;overflow-x:scroll;overflow-y:hidden;scrollbar-width:none;-ms-overflow-style:none}.markets__data::-webkit-scrollbar,.markets__data::-webkit-scrollbar-thumb{display:none;width:0;background:transparent}#market-overview-chart{position:relative;z-index:2}@media:1
# (max-width:975px){.element--markets{border-right:1px:1
# .list--markets{padding-bottom:5px}.element--markets:1
# .market__item{margin-right:10px}.element--markets:1
# .table__row.is-active{background:none}}@media:1
# (max-width:655px){.element--markets{position:fixed;top:50px;left:0;z-index:8;background:#fff;border-bottom:1px:1
# #e1e1e1;height:44px}.element--markets:1
# .markets__list{padding:13px:1
# 14px}}.element--movers{border-left:1px:1
# #e1e1e1;border-right:1px:2
# #e1e1e1;-webkit-flex:0:1
# 200px;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-flow:row:1
# wrap}.element--movers:1
# .header--small{-webkit-flex:1:1
# auto;-ms-flex:1:1
# auto;flex:1:1
# auto}.element--movers:1
# .secondary{margin-left:auto;padding:0}.list--mover{max-width:50%;height:162px;margin-bottom:0}.list--mover:first-of-type{border-right:1px:1
# #e1e1e1}.list--mover:1
# .mover__item:first-of-type:1
# .link{border-top:none}.list--mover:1
# .link{position:relative;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;-webkit-align-items:center;-ms-flex-align:center;align-items:center;height:40.5px;border-bottom:1px:1
# #e1e1e1;padding:0:1
# 8px;text-decoration:none;font-family:Muli,sans-serif;font-size:.85714rem;font-weight:700}.list--mover:1
# .link:hover{background:#f2f6fa;box-shadow:inset:1
# #fff}.element--latestNews{position:relative}.element--latestNews:1
# .group--buttons{position:absolute;right:5px;top:-10px;width:auto;margin:0}.element--latestNews:1
# [class*=scroll]{position:relative;width:20px;height:25px;padding:0}.element--latestNews:1
# [class*=scroll]:2
# 5px);width:0;height:0;border-style:solid;opacity:1;border-width:0:1
# 6px;border-color:transparent:1
# #3677a8}.element--latestNews:1
# .icon:hover{cursor:pointer}.element--latestNews:1
# .scroll-down:1
# .icon{border-width:6px:1
# 5px;border-color:#3677a8:1
# transparent}.element--latestNews:1
# .header--small{padding-left:8px}.element--latestNews:1
# .latestNews__loading{position:relative;background:#f3f3f3;box-shadow:inset:1
# #e1e1e1;min-height:81px}.latestNews__wrapper{height:162px;overflow:hidden}.latestNews__item{display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-flow:row:1
# nowrap;-webkit-justify-content:flex-start;-ms-flex-pack:start;justify-content:flex-start;box-shadow:inset:1
# #e1e1e1}.latestNews__item:hover{background:#f2f6fa;box-shadow:inset:1
# #e1e1e1,inset:8
# -2px:2
# #fff}.latestNews__item>.latestNews__time{-webkit-flex:0:1
# 45px;-ms-flex:0:2
# 45px;flex:0:2
# 45px;-webkit-align-self:center;-ms-flex-item-align:center;-ms-grid-row-align:center;align-self:center;padding-left:8px}.latestNews__item>.latestNews__time+.latestNews__headline{border-bottom:none}.latestNews__item>.latestNews__time+.latestNews__headline:hover{background:none;box-shadow:none}.latestNews__item>.latestNews__time+.latestNews__headline:1
# .link{display:block}.latestNews__headline{display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-flow:row:1
# nowrap;-webkit-align-items:center;-ms-flex-align:center;align-items:center;min-height:40.5px;width:100%;border-bottom:1px:1
# #e1e1e1;padding:5px:1
# 8px}.latestNews__headline:hover{background:#f2f6fa;box-shadow:inset:1
# #fff}.latestNews__time{font:700:1
# .78571rem:1
# Lato,monospace;color:#939393;-webkit-flex:0:1
# 45px}.latestNews__label{font:700:1
# .78571rem/1:1
# Muli,sans-serif;color:#939393;display:inline-block;margin-right:2.5px;text-transform:uppercase}.latestNews__label.updated{color:#939393}.latestNews__label.opinion{color:#3677a8}.latestNews__label.corrected{color:#b51a28}.latestNews__label.breaking{color:#4db74d}.latestNews__label.moneyish{color:#ff716c}.latestNews__label.premium{color:#cb8900}.latestNews__label.barrons{color:#00529c}.latestNews__headline{font:800:1
# .92857rem/1.125:1
# Muli,sans-serif}.latestNews__headline:1
# .text{color:#939393}@media:1
# (max-width:1295px){.element--latestNews{padding-right:0}}.container--trending{bottom:0}.container--trending:1
# .region{margin-bottom:0}.container--trending:1
# .icon--close{position:absolute;top:0;left:calc(50%:1
# 50px);z-index:9;-webkit-transform:translateX(50vw);transform:translateX(50vw);display:block;width:40px;height:40px;line-height:40px;text-align:center;color:#09769d}.container--trending:1
# .icon--close:before{transition:-webkit-transform:1
# ease;transition:transform:2
# ease,:1
# -webkit-transform:1
# ease}.container--trending:1
# .icon--close:hover{background:#042e3d;cursor:pointer}.trending{position:relative;bottom:0;z-index:5;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-flow:row:1
# nowrap;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;-webkit-align-items:center;-ms-flex-align:center;align-items:center;height:40px;transition:bottom:1
# ease}.trending,.trending:after,.trending:before{background:#054055}.trending:1
# .element--ad{position:relative;margin:0:1
# auto;width:205px;margin-bottom:0}.trending:1
# .element--ad>div{margin:0:1
# 65px;width:140px;height:31px;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-ms-flex-align:center;align-items:center;background:hsla(0,0%,100%,.1)}.trending:1
# .element--ad>div:before{display:none}.trending:1
# .element--ad>div:after{content:"Presented:1
# By";top:auto;right:calc(100%:1
# 5px);left:auto}.trending__header{display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-justify-content:flex-start;-ms-flex-pack:start;justify-content:flex-start;-webkit-align-items:center;-ms-flex-align:center;align-items:center;color:hsla(0,0%,100%,.8);margin-right:auto}.trending__provider,.trending__title{display:inline-block}.trending__title{font-size:1rem}.trending__provider{text-decoration:none;font-size:11px;color:#dc8042;padding-left:5px;margin-top:1px}.trending__provider:1
# .provider__logo{position:relative;top:1px;width:45px;height:11px;display:inline-block}.list--trending{border-right:1px:1
# #042e3d;margin:0;width:auto}.trending__item{color:#fff;white-space:nowrap}.trending__link{font:700:1
# .85714rem/40px:1
# Muli,sans-serif;position:relative;padding:0:1
# 10px;border-left:1px:1
# #042e3d;color:#fff;display:block}.trending__link:hover{background:#042e3d}.trending__symbol{opacity:.8;font-weight:700}.trending__change{font-family:Lato,monospace;padding-left:5px}.toggle--trending:checked~.icon--close:before{-webkit-transform:rotate(45deg);transform:rotate(45deg)}.toggle--trending:checked~.region:1
# ...
# fixed2.75%10:1
# fixed2.73%30:1
# refi3.20%15:1
# refi2.77%5/1:1
# ARM3.28%5/1:1
# ARM:1
# refi3.33%National:1
# averages:4
# fromBankrate.com$30K:1
# HELOC1.99%$50K:1
# HELOC5.00%$75K:1
# HELOC1.99%$100K:1
# HELOC5.00%$30K:1
# Home:5
# Equity:4
# Loan5.24%$50K:1
# Loan3.74%$75K:1
# Loan3.74%$100K:1
# Loan4.12%National:1
# fromBankrate.com5:1
# CD0.69%2:1
# CD0.50%1:1
# CD0.46%MMA:1
# $10K+0.19%MMA:1
# $50K+0.26%MMA:1
# Savings0.26%MMA:1
# Savings:1
# Jumbo0.28%National:1
# fromBankrate.com60:1
# Mo:8
# Used:3
# Car4.40%48:1
# Car4.67%36:1
# Car4.74%72:1
# Car4.23%60:1
# Car4.45%48:1
# Car4.26%60:1
# Auto:2
# Refi4.50%36:1
# Refi4.25%National:1
# fromBankrate.comThe:1
# Moneyistgoogletag.cmd.push(function():1
# window.__mwads.slots['ad-the-moneyist-sponsor']:1
# googletag.defineSlot('/2/marketwatch.com/sponsor_homepagetile_moneyologist',:1
# 'ad-the-moneyist-sponsor'):1
# ;googletag.display('ad-the-moneyist-sponsor');:1
# });Quentin:1
# Fottrell:1
# answers:1
# questions:1
# inheritance,:1
# tipping,:1
# weddings,:1
# re-gifting,:1
# tricky:1
# money:1
# issues:1
# relating:1
# friends.:1
# Have:1
# question?Send:1
# Moneyist.‘I’m:1
# understanding:1
# earning:1
# $200,000:1
# much:1
# qualify:1
# decent:1
# check’I:1
# unemployed:1
# tenant:1
# jobs.:1
# enough,:1
# sits:1
# smoking:1
# weed.:1
# Now:1
# wants:1
# discount.:1
# do?My:1
# father:1
# died:1
# COVID-19,:1
# left:1
# will.:1
# My:1
# stepmother:1
# threatened:1
# sell:1
# heirlooms:1
# unless:1
# estate.:1
# do?Should:1
# tell:1
# sister:1
# husband,:1
# notorious:1
# spender,:1
# secret:1
# credit:1
# card?Retirementgoogletag.cmd.push(function():1
# window.__mwads.slots['ad-retirement-sponsor']:1
# googletag.defineSlot('/2/marketwatch.com/sponsor_homepagetile_retirement',:1
# 'ad-retirement-sponsor'):1
# ;googletag.display('ad-retirement-sponsor');:1
# });Are:1
# facing:2
# retirement?:1
# prepareI’m:1
# 32-year-old:1
# mom,:1
# husband:1
# earns:1
# $150,000:1
# year.:1
# Will:1
# ever:1
# enjoy:1
# retirement?I:1
# year-round:1
# outdoor:1
# living:1
# dry:1
# summers:1
# snow:1
# $4,000:1
# month.:1
# Where:1
# retire?The:1
# military:1
# giving:1
# disability:1
# enough:1
# 48?Real:1
# EstateAmerica:1
# eviction:2
# crisis:1
# moratoriums:1
# expire::1
# catastrophe’Democratic:1
# proposed:1
# legislation:1
# expand:1
# moratorium:2
# evictions,:1
# set:1
# expire:1
# days.The:1
# feared:1
# jumbo:1
# debacle:1
# thanks:1
# pound:1
# housing:2
# marketThousands:1
# Silicon:1
# Valley:1
# danger:1
# end:1
# nearsLook:1
# happened:1
# sent:1
# bear:1
# market‘It’s:1
# tax:1
# Black:1
# country’:1
# ways:1
# racism:1
# embedded:1
# industryMansion:1
# GlobalConnecting:1
# affluent:1
# buyers:1
# luxury:1
# listings.A:1
# 40-Acre:1
# Compound:1
# Heart:1
# York’s:1
# Hudson:1
# ValleyWhen:1
# Comes:1
# Property,:1
# Has:1
# Been:1
# ‘A:1
# Time:1
# Reflect’Take:1
# Your:1
# Into:1
# FutureThe:1
# Best:1
# Smart:1
# Bathroom:1
# TechnologyPartner:1
# Content××var:1
# utag_data:1
# "page_access":"free","page_content_source":"MarketWatch","page_site":"MarketWatch","page_site_product":"MW","page_content_language":"en-US","page_content_region":"North_America_USA","page_content_type":"Home","user_exp":"default","reengagement_refresh":"off","user_type":"nonsubscriber","user_tags":"","page_section":"Home:1
# Page","page_id":"/","page_ad_zone":"frontpage","page_subsection":"Home:1
# Page","cms_name":"Peavey"};:1
# utag_dataOriginal:1
# (function:1
# ():1
# (var:1
# prop:1
# utag_data):1
# utag_dataOriginal[prop]:1
# utag_data[prop];:1
# Object.freeze(utag_dataOriginal);:1
# })();var:1
# trackingPageInfo:1
# action::1
# 'Page':1
# };Back:1
# TopMarketWatch:1
# .mw2{fill:#00AC4E;}Copyright:1
# ©:1
# 2020:1
# MarketWatch,:1
# All:2
# rights:1
# reserved.By:1
# using:1
# site:1
# agree:1
# theSubscriber:1
# Agreement:1
# Terms:1
# UseUpdated:1
# 03/26/2020Privacy:1
# NoticeandCookie:1
# Notice.FacebookTwitterLinkedinMarketWatchHelpFeedbackNewsroom:1
# RosterVirtual:1
# ExchangeBigChartsCompanyDow:1
# JonesCode:1
# ConductCorrectionsReprints:1
# LicensingYour:1
# Ad:1
# ChoicesDow:1
# Jones:1
# NetworkThe:1
# JournalBarron'sFinancial:1
# Londonrealtor.comMansion:1
# GlobalKnewzIntraday:1
# Data:1
# provided:2
# byFACTSETand:1
# subject:1
# toterms:1
# use.:1
# Historical:1
# current:1
# end-of-day:1
# byFACTSET.:1
# quotes:2
# local:1
# exchange:2
# time.:1
# Real-time:1
# sale:1
# reflect:1
# trades:1
# Nasdaq:1
# only.:1
# Intraday:1
# delayed:1
# 15:1
# minutes:1
# per:1
# requirements.Trending:1
# TickersPowered:1
# byDKNG-1.78%GLD1.86%ACI-4.47%WHLM109.64%AMD0.22%googletag.cmd.push(function():1
# window.__mwads.slots['ad-trending-tickers']:1
# googletag.defineSlot('/2/marketwatch.com/sponsor_trendingtickers',:1
# 'ad-trending-tickers'):1
# ['TRENDINGTICKERS']):1
# ;googletag.display('ad-trending-tickers');:1
# });var:1
# blueGrass2SilentTest:1
# enabled::1
# false,:1
# endpoint::1
# 'https://mw-silent.bgdev.dowjones.io/bg2':1
# };window.__mwads=window.__mwads||{slots:{}},function(){if(!window.__mwads.gptEnabled)return:1
# void:2
# window.__mwads.log("GPT:1
# disabled");googletag.cmd.push(function(){googletag.pubads().addEventListener("slotRequested",function(e){performance.getEntriesByName("gpt-slotRequested").length||performance.mark("gpt-slotRequested"),e.slot.getSlotElementId()!==window.__mwads.mpuId||performance.getEntriesByName("gpt-mpuRequested").length||performance.mark("gpt-mpuRequested")}),googletag.pubads().addEventListener("slotRenderEnded",function(e){performance.getEntriesByName("gpt-slotRenderEnded").length||performance.mark("gpt-slotRenderEnded"),e.slot.getSlotElementId()!==window.__mwads.mpuId||performance.getEntriesByName("gpt-mpuRenderEnded").length||performance.mark("gpt-mpuRenderEnded");var:1
# t=document.getElementById(e.slot.getSlotElementId());t&&(t.parentElement.classList.remove("is-loading"),t.parentElement.classList.add("is-loaded"))}),googletag.pubads().addEventListener("slotOnload",function(e){performance.getEntriesByName("gpt-slotOnload").length||performance.mark("gpt-slotOnload"),e.slot.getSlotElementId()!==window.__mwads.mpuId||performance.getEntriesByName("gpt-mpuOnLoad").length||performance.mark("gpt-mpuOnLoad")})});var:1
# e,t=1e3,n=1e3,o=!1,a=function(e){return:1
# Object.keys(e).map(function(t){return:1
# e[t]})},i=function(e){return:1
# e.map(function(e){return:1
# e.getSlotElementId()})},r=function(e,t){return:1
# window.__mwads.slots.hasOwnProperty(t.getAttribute("id"))&&e.push(window.__mwads.slots[t.getAttribute("id")]),e},s={LOW:1,MEDIUM:2,HIGH:3},d=[],l={},c=[],u=0,f=s.HIGH,m=function(e,t,n){window.__mwads.log("add:1
# "+e+":4
# display:7
# prereq:4
# importance:4
# "+n),n>=f&&u++,c.push(function(o,a){t(o,g(e,n,a))})},g=function(e,t,n){return:1
# function(){window.__mwads.log("finished:2
# "+t),n(t)}},p=function(e){e&&e.forEach(function(e){window.__mwads.log("displayed:1
# "+e.getSlotElementId()),l[e.getSlotElementId()]=e})},w=function(e,t){if(!o)return:1
# void(d=d.concat(e));var:1
# a=u,s=e.reduce(r,[]),l=!1,m=function(e){!l&&e&&(l=!0,googletag.cmd.push(function(){window.__mwads.log("gpt:1
# refresh:1
# "+i(e).join(",")),googletag.pubads().refresh(e),p(e)}))};if(c.length>0){window.__mwads.log("starting:1
# prereqs...");for(var:1
# g=setTimeout(m.bind(s),n),w=0;w<c.length;w++)c[w](s,function(e){e>=f&&--a,0>=a&&(clearTimeout(g),window.__mwads.log("...finished:1
# prereqs"),m(s))})}else:1
# window.__mwads.log("no:1
# prereqs"),m(s)},h=[],_=0,y=s.HIGH,v=function(e,t,n){window.__mwads.log("add:1
# load:3
# "+n),n>=y&&_++,h.push(function(){t(E(e,n))})},E=function(e,t){return:1
# "+t),t>=y&&0===--_&&b()}},b=function(){clearTimeout(e),window.__mwads.log("go:1
# ads,:1
# go"),o||(o=!0,w(d),d=[])};window.addEventListener("lazybeforeunveil",function(e){e.target.classList.contains("j-ad")&&w([e.target])}),googletag.cmd.push(function(){"undefined"!=typeof:1
# window.pxSegmentIDs&&a(window.__mwads.slots).forEach(function(e){window.__mwads.log("psg:1
# "+e.getSlotElementId()),e.setTargeting("psg",window.pxSegmentIDs.split(","))})}),googletag.cmd.push(function(){var:1
# e=/curated--(A|B|C|D)/i;document.querySelectorAll(".component--curated").forEach(function(t){var:1
# n=t.querySelector(".is-native:1
# .j-ad");if(n&&window.__mwads.slots.hasOwnProperty(n.getAttribute("id"))){var:1
# o=e.exec(t.className);o&&o.length>1&&(window.__mwads.slots[n.getAttribute("id")].setTargeting("ntvPlacement",window.__mwads.curatedMap[o[1]]),window.__mwads.slots[n.getAttribute("id")].setTargeting("pagetemplate","layout"+o[1]))}})}),window.addEventListener("curatedUpdate",function(){var:1
# e=document.querySelector(".component--curated:1
# .is-native");e&&"undefined"!=typeof:1
# PostRelease&&"function"==typeof:1
# PostRelease.Start&&MarketWatch&&MarketWatch.Settings&&MarketWatch.Settings.snare&&PostRelease.Start({ptd:MarketWatch.Settings.snare.nativeIds})}),window.addEventListener("viewModeChanged",function(){googletag.cmd.push(function(){window.__mwads.log("view:1
# refreshing..."),googletag.pubads().refresh(a(l))})}),__mwads.prebidEnabled&&v("prebid",function(e){pbjs.que.push(function(){window.__mwads.log("prebid:1
# library:2
# ready"),m("prebid",function(e,t){googletag.cmd.push(function(){pbjs.loadPrebidAds(e.map(function(e){return:1
# e.getSlotElementId()}),function(){t(),window.__mwads.log("prebid:1
# done")})})},s.HIGH),e()})},s.HIGH),__mwads.moatEnabled&&v("moat",function(e){var:1
# t=function(){window.__mwads.log("moat:1
# ready"),m("moat",function(e,t){googletag.cmd.push(function(){e.forEach(function(e){moatPrebidApi.setMoatTargetingForSlot(e)}),window.__mwads.log("moat:1
# done")}),t()},s.HIGH),e()};window.moatPrebidApi&&"function"==typeof:1
# window.moatPrebidApi.slotDataAvailable&&window.moatPrebidApi.slotDataAvailable()?t():window.moatYieldReady=t},s.HIGH),googletag.cmd.push(function(){0===_?(window.__mwads.log("no:1
# prereqs"),b()):(h.forEach(function(e){e()}),e=setTimeout(b,t))}),window.__mwads.display=function(e){if(e){var:1
# t=Array.isArray(e)?e:[e];w(t)}}}(),/*!:1
# lazysizes:1
# v1.4.0:1
# !function(e,t){var:1
# n=t(e,e.document);e.lazySizes=n,"object"==typeof:1
# module&&module.exports?module.exports=n:"function"==typeof:1
# define&&define.amd&&define(n)}(window,function(e,t){"use:1
# strict";if(t.getElementsByClassName){var:1
# n,o=t.documentElement,a=e.HTMLPictureElement&&"sizes"in:1
# t.createElement("img"),i="addEventListener",r="getAttribute",s=e[i],d=e.setTimeout,l=e.requestAnimationFrame||d,c=/^picture$/i,u=["load","error","lazyincluded","_lazyloaded"],f={},m=Array.prototype.forEach,g=function(e,t){return:1
# f[t]||(f[t]=new:1
# RegExp("(\\s|^)"+t+"(\\s|$)")),f[t].test(e[r]("class")||"")&&f[t]},p=function(e,t){g(e,t)||e.setAttribute("class",(e[r]("class")||"").trim()+":1
# "+t)},w=function(e,t){var:1
# n;(n=g(e,t))&&e.setAttribute("class",(e[r]("class")||"").replace(n,":1
# "))},h=function(e,t,n){var:1
# o=n?i:"removeEventListener";n&&h(e,t),u.forEach(function(n){e[o](n,t)})},_=function(e,n,o,a,i){var:1
# r=t.createEvent("CustomEvent");return:1
# r.initCustomEvent(n,!a,!i,o||{}),e.dispatchEvent(r),r},y=function(t,o){var:1
# i;!a&&(i=e.picturefill||n.pf)?i({reevaluate:!0,elements:[t]}):o&&o.src&&(t.src=o.src)},v=function(e,t){return(getComputedStyle(e,null)||{})[t]},E=function(e,t,o){for(o=o||e.offsetWidth;o<n.minSize&&t&&!e._lazysizesWidth;)o=t.offsetWidth,t=t.parentNode;return:1
# o},b=function(t){var:1
# n,o=0,a=e.Date,i=function(){n=!1,o=a.now(),t()},r=function(){d(i)},s=function(){l(r)};return:1
# function(){if(!n){var:1
# e=125-(a.now()-o);n=!0,6>e&&(e=6),d(s,e)}}},z=function(){var:1
# a,u,f,E,z,C,S,I,M,N,R,L,q,B,H,P=/^img$/i,k=/^iframe$/i,T="onscroll"in:1
# e&&!/glebot/.test(navigator.userAgent),W=0,O=0,x=0,D=0,G=function(e){x--,e&&e.target&&h(e.target,G),(!e||0>x||!e.target)&&(x=0)},j=function(e,n){var:1
# a,i=e,r="hidden"==v(t.body,"visibility")||"hidden"!=v(e,"visibility");for(M-=n,L+=n,N-=n,R+=n;r&&(i=i.offsetParent)&&i!=t.body&&i!=o;)r=(v(i,"opacity")||1)>0,r&&"visible"!=v(i,"overflow")&&(a=i.getBoundingClientRect(),r=R>a.left&&N<a.right&&L>a.top-1&&M<a.bottom+1);return:1
# r},F=function(){var:1
# e,t,i,s,d,l,c,m,g;if((z=n.loadMode)&&8>x&&(e=a.length)){t=0,D++,null==B&&("expand"in:1
# n||(n.expand=o.clientHeight>600?o.clientWidth>860?500:410:359),q=n.expand,B=q*n.expFactor),B>O&&1>x&&D>3&&z>2?(O=B,D=0):O=z>1&&D>2&&6>x?q:W;for(;e>t;t++)if(a[t]&&!a[t]._lazyRace)if(T)if((m=a[t][r]("data-expand"))&&(l=1*m)||(l=O),g!==l&&(S=innerWidth+l*H,I=innerHeight+l,c=-1*l,g=l),i=a[t].getBoundingClientRect(),(L=i.bottom)>=c&&(M=i.top)<=I&&(R=i.right)>=c*H&&(N=i.left)<=S&&(L||R||N||M)&&(f&&3>x&&!m&&(3>z||4>D)||j(a[t],l))){if(Q(a[t]),d=!0,x>9)break}else!d&&f&&!s&&4>x&&4>D&&z>2&&(u[0]||n.preloadAfterLoad)&&(u[0]||!m&&(L||R||N||M||"auto"!=a[t][r](n.sizesAttr)))&&(s=u[0]||a[t]);else:1
# Q(a[t]);s&&!d&&Q(s)}},$=b(F),U=function(e){p(e.target,n.loadedClass),w(e.target,n.loadingClass),h(e.target,U)},Y=function(e,t){try{e.contentWindow.location.replace(t)}catch(n){e.src=t}},J=function(e){var:1
# t,o,a=e[r](n.srcsetAttr);(t=n.customMedia[e[r]("data-media")||e[r]("media")])&&e.setAttribute("media",t),a&&e.setAttribute("srcset",a),t&&(o=e.parentNode,o.insertBefore(e.cloneNode(),e),o.removeChild(e))},K=function(){var:1
# e,t=[],n=function(){for(;t.length;)t.shift()();e=!1};return:1
# function(o){t.push(o),e||(e=!0,l(n))}}(),Q=function(e){var:1
# t,o,a,i,s,l,u,v=P.test(e.nodeName),b=v&&(e[r](n.sizesAttr)||e[r]("sizes")),z="auto"==b;(!z&&f||!v||!e.src&&!e.srcset||e.complete||g(e,n.errorClass))&&(z&&(u=e.offsetWidth),e._lazyRace=!0,x++,K(function(){e._lazyRace&&delete:1
# e._lazyRace,(s=_(e,"lazybeforeunveil")).defaultPrevented||(b&&(z?(A.updateElem(e,!0,u),p(e,n.autosizesClass)):e.setAttribute("sizes",b)),o=e[r](n.srcsetAttr),t=e[r](n.srcAttr),v&&(a=e.parentNode,i=a&&c.test(a.nodeName||"")),l=s.detail.firesLoad||"src"in:1
# e&&(o||t||i),s={target:e},l&&(h(e,G,!0),clearTimeout(E),E=d(G,2500),p(e,n.loadingClass),h(e,U,!0)),i&&m.call(a.getElementsByTagName("source"),J),o?e.setAttribute("srcset",o):t&&!i&&(k.test(e.nodeName)?Y(e,t):e.src=t),(o||i)&&y(e,{src:t})),w(e,n.lazyClass),(!l||e.complete)&&(l?G(s):x--,U(s))}))},V=function(){if(!f){if(Date.now()-C<999)return:1
# d(V,999);var:1
# e,t=function(){n.loadMode=3,$()};f=!0,n.loadMode=3,x||(D?$():d(F)),s("scroll",function(){3==n.loadMode&&(n.loadMode=2),clearTimeout(e),e=d(t,99)},!0)}};return{_:function(){C=Date.now(),a=t.getElementsByClassName(n.lazyClass),u=t.getElementsByClassName(n.lazyClass+":1
# "+n.preloadClass),H=n.hFac,s("scroll",$,!0),s("resize",$,!0),e.MutationObserver?new:1
# MutationObserver($).observe(o,{childList:!0,subtree:!0,attributes:!0}):(o[i]("DOMNodeInserted",$,!0),o[i]("DOMAttrModified",$,!0),setInterval($,999)),s("hashchange",$,!0),["focus","mouseover","click","load","transitionend","animationend","webkitAnimationEnd"].forEach(function(e){t[i](e,$,!0)}),/d$|^c/.test(t.readyState)?V():(s("load",V),t[i]("DOMContentLoaded",$),d(V,2e4)),$(a.length>0)},checkElems:$,unveil:Q}}(),A=function(){var:1
# e,o=function(e,t,n){var:1
# o,a,i,r,s=e.parentNode;if(s&&(n=E(e,s,n),r=_(e,"lazybeforesizes",{width:n,dataAttr:!!t}),!r.defaultPrevented&&(n=r.detail.width,n&&n!==e._lazysizesWidth))){if(e._lazysizesWidth=n,n+="px",e.setAttribute("sizes",n),c.test(s.nodeName||""))for(o=s.getElementsByTagName("source"),a=0,i=o.length;i>a;a++)o[a].setAttribute("sizes",n);r.detail.dataAttr||y(e,r.detail)}},a=function(){var:1
# t,n=e.length;if(n)for(t=0;n>t;t++)o(e[t])},i=b(a);return{_:function(){e=t.getElementsByClassName(n.autosizesClass),s("resize",i)},checkElems:i,updateElem:o}}(),C=function(){C.i||(C.i=!0,A._(),z._())};return:1
# function(){var:1
# t,o={lazyClass:"lazyload",loadedClass:"lazyloaded",loadingClass:"lazyloading",preloadClass:"lazypreload",errorClass:"lazyerror",autosizesClass:"lazyautosizes",srcAttr:"data-src",srcsetAttr:"data-srcset",sizesAttr:"data-sizes",minSize:40,customMedia:{},init:!0,expFactor:1.7,hFac:.8,loadMode:2};n=e.lazySizesConfig||e.lazysizesConfig||{};for(t:1
# o)t:1
# n||(n[t]=o[t]);e.lazySizesConfig=n,d(function(){n.init&&C()})}(),{cfg:n,autoSizer:A,loader:z,init:C,uP:y,aC:p,rC:w,hC:g,fire:_,gW:E}}});Advanced:1
# SearchSubmit:1
# keyword:1
# resultsgoogletag.cmd.push(function():1
# window.__mwads.slots['ad-search-sponsor']:1
# googletag.defineSlot('/2/marketwatch.com/sponsor_search',:1
# 'ad-search-sponsor'):1
# ['nativesearch']):1
# ['volatility075','red']):1
# ;googletag.display('ad-search-sponsor');:1
# });ListingsColumnsAuthorsTopicsNo:1
# results:1
# foundPrivateVideo:1
# Center×(function(a,b,c,d){:1
# a='//tags.tiqcdn.com/utag/wsjdn/marketwatch/prod/utag.js';b=document;c='script';d=b.createElement(c);d.src=a;d.type='text/java'+c;d.async=true;a=b.getElementsByTagName(c)[0];a.parentNode.insertBefore(d,a);})();:1
