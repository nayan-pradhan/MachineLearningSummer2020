# %%
# Import
import os
import nltk
import nltk.corpus

# %%
# Specify Website 
import urllib.request
response = urllib.request.urlopen('https://www.apple.com/iphone-11-pro/')
html = response.read()
print(html)
# Out:
# b'\n<!DOCTYPE html>\n<html class="no-js" xmlns="http://www.w3.org/1999/xhtml" xml:lang="en-US" lang="en-US" dir="ltr" prefix="og: http://ogp.me/ns#">\n<head>\n\t\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n<meta charset="utf-8" />\n<link rel="canonical" href="https://www.apple.com/iphone-11/" />\n\n\n\t\n\t<link rel="alternate" href="https://www.apple.com/ae-ar/iphone-11/" hreflang="ar-AE" /><link rel="alternate" href="https://www.apple.com/ae/iphone-11/" hreflang="en-AE" /><link rel="alternate" href="https://www.apple.com/am/iphone-11/" hreflang="en-AM" /><link rel="alternate" href="https://www.apple.com/at/iphone-11/" hreflang="de-AT" /><link rel="alternate" href="https://www.apple.com/au/iphone-11/" hreflang="en-AU" /><link rel="alternate" href="https://www.apple.com/befr/iphone-11/" hreflang="fr-BE" /><link rel="alternate" href="https://www.apple.com/benl/iphone-11/" hreflang="nl-BE" /><link rel="alternate" href="https://www.apple.com/bg/iphone-11/" hreflang="bg-BG" /><link rel="alternate" href="https://www.apple.com/bh-ar/iphone-11/" hreflang="ar-BH" /><link rel="alternate" href="https://www.apple.com/bh/iphone-11/" hreflang="en-BH" /><link rel="alternate" href="https://www.apple.com/br/iphone-11/" hreflang="pt-BR" /><link rel="alternate" href="https://www.apple.com/bw/iphone-11/" hreflang="en-BW" /><link rel="alternate" href="https://www.apple.com/ca/fr/iphone-11/" hreflang="fr-CA" /><link rel="alternate" href="https://www.apple.com/ca/iphone-11/" hreflang="en-CA" /><link rel="alternate" href="https://www.apple.com/cf/iphone-11/" hreflang="fr-CF" /><link rel="alternate" href="https://www.apple.com/chde/iphone-11/" hreflang="de-CH" /><link rel="alternate" href="https://www.apple.com/chfr/iphone-11/" hreflang="fr-CH" /><link rel="alternate" href="https://www.apple.com/ci/iphone-11/" hreflang="fr-CI" /><link rel="alternate" href="https://www.apple.com/cl/iphone-11/" hreflang="es-CL" /><link rel="alternate" href="https://www.apple.com/cm/iphone-11/" hreflang="fr-CM" /><link rel="alternate" href="https://www.apple.com/co/iphone-11/" hreflang="es-CO" /><link rel="alternate" href="https://www.apple.com/cz/iphone-11/" hreflang="cs-CZ" /><link rel="alternate" href="https://www.apple.com/de/iphone-11/" hreflang="de-DE" /><link rel="alternate" href="https://www.apple.com/dk/iphone-11/" hreflang="da-DK" /><link rel="alternate" href="https://www.apple.com/ee/iphone-11/" hreflang="et-EE" /><link rel="alternate" href="https://www.apple.com/eg-ar/iphone-11/" hreflang="ar-EG" /><link rel="alternate" href="https://www.apple.com/eg/iphone-11/" hreflang="en-EG" /><link rel="alternate" href="https://www.apple.com/es/iphone-11/" hreflang="es-ES" /><link rel="alternate" href="https://www.apple.com/fi/iphone-11/" hreflang="fi-FI" /><link rel="alternate" href="https://www.apple.com/fr/iphone-11/" hreflang="fr-FR" /><link rel="alternate" href="https://www.apple.com/gn/iphone-11/" hreflang="fr-GN" /><link rel="alternate" href="https://www.apple.com/gq/iphone-11/" hreflang="fr-GQ" /><link rel="alternate" href="https://www.apple.com/gr/iphone-11/" hreflang="el-GR" /><link rel="alternate" href="https://www.apple.com/gw/iphone-11/" hreflang="en-GW" /><link rel="alternate" href="https://www.apple.com/hk/en/iphone-11/" hreflang="en-HK" /><link rel="alternate" href="https://www.apple.com/hk/iphone-11/" hreflang="zh-HK" /><link rel="alternate" href="https://www.apple.com/hr/iphone-11/" hreflang="hr-HR" /><link rel="alternate" href="https://www.apple.com/hu/iphone-11/" hreflang="hu-HU" /><link rel="alternate" href="https://www.apple.com/id/iphone-11/" hreflang="en-ID" /><link rel="alternate" href="https://www.apple.com/ie/iphone-11/" hreflang="en-IE" /><link rel="alternate" href="https://www.apple.com/il/iphone-11/" hreflang="en-IL" /><link rel="alternate" href="https://www.apple.com/in/iphone-11/" hreflang="en-IN" /><link rel="alternate" href="https://www.apple.com/iphone-11/" hreflang="en-US" /><link rel="alternate" href="https://www.a ...

# %%
# Remove all html5 elements form website using BeautifulSoup
from bs4 import BeautifulSoup
soup = BeautifulSoup(html, 'html5lib')
text = soup.get_text(strip = True)
print(text)
# Out:
# iPhone 11 - AppleGlobal Nav Open MenuGlobal Nav Close MenuAppleShopping Bag+Search apple.comCancelAppleMaciPadiPhoneWatchTVMusicSupportShopping Bag+CanceliPhone 11Local Nav Open MenuLocal Nav Close MenuOverviewTech SpecsBuyif (document.querySelector && window.getComputedStyle && window.devicePixelRatio) {
# 								var videoEl = document.querySelector("#hero-video");
# 								var viewportEmitterEl = document.querySelector("#ac-ln-viewport-emitter");
# 								if (videoEl && viewportEmitterEl) {
# 									var viewport = getComputedStyle(viewportEmitterEl, ':before').content;
# 									var suffix = window.devicePixelRatio > 1 ? '-2x' : '';
# 									viewport = viewport.replace(/(ac-localnav:)|\"|\'/g, "") + suffix;
# 									var src = videoEl.getAttribute("data-src-" + viewport);
# 									videoEl.src = src;
# 								}
# 							}iPhone 11Just theright amount of everything.A new dual‑camera system captures more of what you see and love. The fastest chip ever in a smartphone and all‑day battery life let you do more and charge less. And the highest‑quality video in a smartphone, so your memories look better than ever.From$19.95/mo.or$479with trade-in.*Watch the keynoteWatch the filmSelect a finishPurpleYellowGreenBlackWhite(PRODUCT)REDLove at first, second, third, fourth, fifth, and sixth sight.See iPhone 11 in ARSee iPhone 11 in ARSupercolorful 6.1“ all-screen Liquid Retina display.Strong and durable aerospace-grade aluminum.Precision milled from a single sheet of glass.It just got a whole lot harder to take a bad photo.All‑new dual‑camera system.Take your photos from wide to ultra wide. A redesigned interface uses the new Ultra Wide camera to show you what’s happening outside the frame — and lets you capture it. Shoot and edit videos as easily as you do photos. It’s the world’s most popular camera, now with a whole new perspective.12MP WideThe new Wide sensor has 100 percent Focus Pixels for up to three times faster autofocus in low light.12MP Ultra WideCapturing four times more scene, it’s great for landscapes, travel, groups, large interiors, and action shots.Compare with iPhone 11 ProComparecamera systemwith iPhone 11 ProiPhone 11 Prohas the same Wide and Ultra Wide cameras, along with a new Telephoto camera. This triple‑camera system gives you a combined four times optical zoom range for more framing options.Kick your video up a notch. Over a smidge. Or down a hair.CropSkewFiltersShoot and edit the highest-quality video in a smartphone.iPhone 11 shoots beautifully sharp 4K video at 60 fps across all its cameras. The Ultra Wide camera captures four times more scene, so it’s perfect for action shots like your dog catching a frisbee. If you’re recording a performance — say, your kid’s piano recital — when you zoom in, the audio zooms too. And now you can edit videos as easily as you do photos.“OK, everyone, scooch out a bit.”New Ultra Wide camera.Go big — the new Ultra Wide camera captures four times more scene. Think breathtaking landscapes that go on forever. Capturing the entire stage and crowd at a music festival. And vacation shots that show the whole family — including the views you traveled 11,000 miles for.Not enough light? No problem.Introducing Night mode.Shooting in low light doesn’t have to be a shot in the dark. Night mode is a new feature that turns on automatically for low‑light photos like you’ve never seen. There’s no need for flash, colors are more natural, and photos are brighter.Night mode offNight mode onSee the advanced technology that goes into every Night mode shotThe power behind beautiful night shots.Getting great shots in low light is one of photography’s perpetual challenges. The shutter needs to stay open longer, which can lead to blur. Then there’s the tricky task of keeping detail in the shadows without overexposing lighter areas. And making sure colors stay natural‑looking.With iPhone 11 and iPhone 11 Pro, a new Wide camera sensor works with intelligent software and A13 Bionic to let you do what was never possible on iPhone: get beautiful, detailed images in drastically lower light.Night mode comes on automatically when needed — say, in a candlelit restaurant. When you tap the shutter, the camera takes multiple images while optical image stabilization steadies the lens.Then the camera software goes to work. It aligns images to correct for movement. It discards the sections with too much blur and fuses sharper ones. It adjusts contrast so everything stays in balance. It fine‑tunes colors so they look natural. Then it intelligently de‑noises and enhances details to produce the final image.It all adds up to night shots that stand apart — with more detail, less noise, and an authentic sense of time and place.Portrait-perfect.Take portraits to new places.With new kinds of portraits and more lighting controls, the dua ...
#
# 			2020
# 			Apple Inc. All rights reserved.Privacy PolicyTerms of UseSales and RefundsLegalSite Map{
# 		"@context": "http://schema.org",
# 		"@id": "https://www.apple.com/#organization",
# 		"@type": "Organization",
# 		"name": "Apple",
# 		"url": "https://www.apple.com/",
# 		"logo": "https://www.apple.com/ac/structured-data/images/knowledge_graph_logo.png?202006241657",
# 		"subOrganization": {
# 			"@type": "Organization",
# 			"name": "Apple Support",
# 			"url": "https://support.apple.com",
# 	    "@id": "https://support.apple.com/#organization"
# 		},
# 		"contactPoint": [
# 			{
# 				"@type": "ContactPoint",
# 				"telephone": "+1-800-692-7753",
# 				"contactType": "sales",
# 				"areaServed": "US"
# 			},
# 			{
# 				"@type": "ContactPoint",
# 				"telephone": "+1-800-275-2273",
# 				"contactType": "technical support",
# 				"areaServed": "US",
# 				"availableLanguage": ["EN", "ES"]
# 			},
# 			{
# 				"@type": "ContactPoint",
# 				"telephone": "+1-800-275-2273",
# 				"contactType": "customer support",
# 				"areaServed": "US",
# 				"availableLanguage": ["EN", "ES"]
# 			}
# 		],
# 		"sameAs": [
# 			"http://www.wikidata.org/entity/Q312",
# 			"https://www.youtube.com/user/Apple",
# 			"https://www.linkedin.com/company/apple",
# 			"https://www.facebook.com/Apple",
# 			"https://www.twitter.com/Apple"
# 		]
# 	}{
# 			"@context": "http://schema.org",
# 			"@type": "Product",
# 			"@id": "https://www.apple.com/iphone-11/#product",
# 			"manufacturer": {
# 				"@id": "https://www.apple.com/#organization"
# 			},
# 			"brand": {
# 				"@id": "https://www.apple.com/iphone/#brand"
# 			},
# 			"name": "iPhone 11",
# 			"description": "Meet iPhone 11. All-new dual-camera system with Ultra Wide and Night mode. All-day battery. Six new colors. And the A13 Bionic, our fastest chip ever.",
# 			"url": "https://www.apple.com/iphone-11/",
# 			"mainEntityOfPage": "https://www.apple.com/iphone-11/",
# 			"image": "https://www.apple.com/v/iphone-11/d/images/meta/og__f2jtwncwsl2e_overview.png",
# 			"potentialAction": {
# 				"@type": "BuyAction",
# 				"seller": {
# 					"@id": "https://www.apple.com/#organization"
# 				},
# 				"url": ["https://www.apple.com/us/shop/goto/buy_iphone/iphone_11"]
# 			}
# 		}

# %%
# Convert the words into individual tokens
tokens = [t for t in text.split()]
print(tokens)
# Out:
# ['iPhone', '11', '-', 'AppleGlobal', 'Nav', 'Open', 'MenuGlobal', 'Nav', 'Close', 'MenuAppleShopping', 'Bag+Search', 'apple.comCancelAppleMaciPadiPhoneWatchTVMusicSupportShopping', 'Bag+CanceliPhone', '11Local', 'Nav', 'Open', 'MenuLocal', 'Nav', 'Close', 'MenuOverviewTech', 'SpecsBuyif', '(document.querySelector', '&&', 'window.getComputedStyle', '&&', 'window.devicePixelRatio)', '{', 'var', 'videoEl', '=', 'document.querySelector("#hero-video");', 'var', 'viewportEmitterEl', '=', 'document.querySelector("#ac-ln-viewport-emitter");', 'if', '(videoEl', '&&', 'viewportEmitterEl)', '{', 'var', 'viewport', '=', 'getComputedStyle(viewportEmitterEl,', "':before').content;", 'var', 'suffix', '=', 'window.devicePixelRatio', '>', '1', '?', "'-2x'", ':', "'';", 'viewport', '=', 'viewport.replace(/(ac-localnav:)|\\"|\\\'/g,', '"")', '+', 'suffix;', 'var', 'src', '=', 'videoEl.getAttribute("data-src-"', '+', 'viewport);', 'videoEl.src', '=', 'src;', '}', '}iPhone', '11Just', 'theright', 'amount', 'of', 'everything.A', 'new', 'dual‑camera', 'system', 'captures', 'more', 'of', 'what', 'you', 'see', 'and', 'love.', 'The', 'fastest', 'chip', 'ever', 'in', 'a', 'smartphone', 'and', 'all‑day', 'battery', 'life', 'let', 'you', 'do', 'more', 'and', 'charge', 'less.', 'And', 'the', 'highest‑quality', 'video', 'in', 'a', 'smartphone,', 'so', 'your', 'memories', 'look', 'better', 'than', 'ever.From$19.95/mo.or$479with', 'trade-in.*Watch', 'the', 'keynoteWatch', 'the', 'filmSelect', 'a', 'finishPurpleYellowGreenBlackWhite(PRODUCT)REDLove', 'at', 'first,', 'second,', 'third,', 'fourth,', 'fifth,', 'and', 'sixth', 'sight.See', 'iPhone', '11', 'in', 'ARSee', 'iPhone', '11', 'in', 'ARSupercolorful', '6.1“', 'all-screen', 'Liquid', 'Retina', 'display.Strong', 'and', 'durable', 'aerospace-grade', 'aluminum.Precision', 'milled', 'from', 'a', 'single', 'sheet', 'of', 'glass.It', 'just', 'got', 'a', 'whole', 'lot', 'harder', 'to', 'take', 'a', 'bad', 'photo.All‑new', 'dual‑camera', 'system.Take', 'your', 'photos', 'from', 'wide', 'to', 'ultra', 'wide.', 'A', 'redesigned', 'interface', 'uses', 'the', 'new', 'Ultra', 'Wide', 'camera', 'to', 'show', 'you', 'what’s', 'happening', 'outside', 'the', 'frame', '—', 'and', 'lets', 'you', 'capture', 'it.', 'Shoot', 'and', 'edit', 'videos', 'as', 'easily', 'as', 'you', 'do', 'photos.', 'It’s', 'the', 'world’s', 'most', 'popular', 'camera,', 'now', 'with', 'a', 'whole', 'new', 'perspective.12MP', 'WideThe', 'new', 'Wide', 'sensor', 'has', '100', 'percent', 'Focus', 'Pixels', 'for', 'up', 'to', 'three', 'times', 'faster', 'autofocus', 'in', 'low', 'light.12MP', 'Ultra', 'WideCapturing', 'four', 'times', 'more', 'scene,', 'it’s', 'great', 'for', 'landscapes,', 'travel,', 'groups,', 'large', 'interiors,', 'and', 'action', 'shots.Compare', 'with', 'iPhone', '11', 'ProComparecamera', 'systemwith', 'iPhone', '11', 'ProiPhone', '11', 'Prohas', 'the', 'same', 'Wide', 'and', 'Ultra', 'Wide', 'cameras,', 'along', 'with', 'a', 'new', 'Telephoto', 'camera.', 'This', 'triple‑camera', 'system', 'gives', 'you', 'a', 'combined', 'four', 'times', 'optical', 'zoom', 'range', 'for', 'more', 'framing', 'options.Kick', 'your', 'video', 'up', 'a', 'notch.', 'Over', 'a', 'smidge.', 'Or', 'down', 'a', 'hair.CropSkewFiltersShoot', 'and', 'edit', 'the', 'highest-quality', 'video', 'in', 'a', 'smartphone.iPhone', '11', 'shoots', 'beautifully', 'sharp', '4K', 'video', 'at', '60', 'fps', 'across', 'all', 'its', 'cameras.', 'The', 'Ultra', 'Wide', 'camera', 'captures', 'four', 'times', 'more', 'scene,', 'so', 'it’s', 'perfect', 'for', 'action', 'shots', 'like', 'your', 'dog', 'catching', 'a', 'frisbee.', 'If', 'you’re', 'recording', 'a', 'performance', '—', 'say,', 'your', 'kid’s', 'piano', 'recital', '—', 'when', 'you', 'zoom', 'in,', 'the', 'audio', 'zooms', 'too.', 'And', 'now', 'you', 'can', 'edit', 'videos', 'as', 'easily', 'as', 'you', 'do', 'photos.“OK,', 'everyone,', 'scooch', 'out', 'a', 'bit.”New', 'Ultra', 'Wide', 'camera.Go', 'big', '—', ...

# %%
from nltk.corpus import stopwords
sr = stopwords.words('english')
clean_tokens = tokens[:]
for token in tokens:
    if token in stopwords.words('english'):
        clean_tokens.remove(token)
freq = nltk.FreqDist(clean_tokens)
for key, val in freq.items():
    print(str(key) + ":" + str(val))
freq.plot(20, cumulative = False)
# Out:
# iPhone:58
# 11:38
# -:1
# AppleGlobal:1
# Nav:4
# Open:2
# MenuGlobal:1
# Close:2
# MenuAppleShopping:1
# Bag+Search:1
# apple.comCancelAppleMaciPadiPhoneWatchTVMusicSupportShopping:1
# Bag+CanceliPhone:1
# 11Local:1
# MenuLocal:1
# MenuOverviewTech:1
# SpecsBuyif:1
# (document.querySelector:1
# &&:3
# window.getComputedStyle:1
# window.devicePixelRatio):1
# {:10
# var:5
# videoEl:1
# =:7
# document.querySelector("#hero-video");:1
# viewportEmitterEl:1
# document.querySelector("#ac-ln-viewport-emitter");:1
# (videoEl:1
# viewportEmitterEl):1
# viewport:2
# getComputedStyle(viewportEmitterEl,:1
# ':before').content;:1
# suffix:1
# window.devicePixelRatio:1
# >:1
# 1:1
# ?:1
# '-2x':1
# ::1
# '';:1
# viewport.replace(/(ac-localnav:)|\"|\'/g,:1
# ""):1
# +:2
# suffix;:1
# src:1
# videoEl.getAttribute("data-src-":1
# viewport);:1
# videoEl.src:1
# src;:1
# }:4
# }iPhone:1
# 11Just:1
# theright:1
# amount:1
# everything.A:1
# new:21
# dual‑camera:2
# system:4
# captures:3
# see:2
# love.:1
# The:3
# fastest:3
# chip:6
# ever:4
# smartphone:2
# all‑day:1
# battery:6
# life:3
# let:3
# charge:3
# less.:1
# And:16
# highest‑quality:2
# video:13
# smartphone,:1
# memories:1
# look:5
# better:1
# ever.From$19.95/mo.or$479with:1
# trade-in.*Watch:1
# keynoteWatch:1
# filmSelect:1
# finishPurpleYellowGreenBlackWhite(PRODUCT)REDLove:1
# first,:1
# second,:2
# third,:1
# fourth,:1
# fifth,:1
# sixth:1
# sight.See:1
# ARSee:1
# ARSupercolorful:1
# 6.1“:1
# all-screen:2
# Liquid:2
# Retina:3
# display.Strong:1
# durable:1
# aerospace-grade:1
# aluminum.Precision:1
# milled:1
# single:1
# sheet:1
# glass.It:1
# got:1
# whole:3
# lot:1
# harder:1
# take:3
# bad:1
# photo.All‑new:1
# system.Take:1
# photos:3
# wide:1
# ultra:1
# wide.:1
# A:1
# redesigned:1
# interface:1
# uses:3
# Ultra:8
# Wide:9
# camera:9
# show:2
# what’s:1
# happening:1
# outside:1
# frame:1
# —:13
# lets:4
# capture:2
# it.:2
# Shoot:1
# edit:3
# videos:2
# easily:2
# photos.:1
# It’s:4
# world’s:1
# popular:1
# camera,:1
# perspective.12MP:1
# WideThe:1
# sensor:2
# 100:1
# percent:3
# Focus:1
# Pixels:1
# three:1
# times:5
# faster:4
# autofocus:1
# low:4
# light.12MP:1
# WideCapturing:1
# four:4
# scene,:2
# it’s:7
# great:2
# landscapes,:1
# travel,:1
# groups,:1
# large:1
# interiors,:1
# action:2
# shots.Compare:1
# ProComparecamera:1
# systemwith:1
# ProiPhone:4
# Prohas:1
# cameras,:1
# along:1
# Telephoto:1
# camera.:3
# This:2
# triple‑camera:1
# gives:2
# combined:1
# optical:2
# News+Apple:1
# TV+Apple:1
# ArcadeApple:1
# BooksApple:1
# CardiCloudAccountOpen:1
# MenuManage:1
# IDApple:1
# Store:2
# AccountiCloud.comApple:1
# StoreOpen:1
# MenuFind:1
# StoreShop:1
# OnlineGenius:1
# BarToday:1
# AppleApple:1
# CampApple:1
# AppRefurbished:1
# ClearanceFinancingApple:1
# InOrder:1
# StatusShopping:1
# HelpFor:1
# BusinessOpen:1
# BusinessShop:1
# BusinessFor:1
# EducationOpen:1
# EducationShop:1
# K-12Shop:1
# CollegeFor:1
# HealthcareOpen:1
# HealthcareHealth:1
# WatchHealth:1
# Records:1
# iPhoneFor:1
# GovernmentOpen:1
# MenuShop:1
# GovernmentShop:1
# Veterans:1
# MilitaryApple:1
# ValuesOpen:1
# MenuAccessibilityEducationEnvironmentInclusion:1
# DiversityPrivacySupplier:1
# ResponsibilityAbout:1
# AppleOpen:1
# MenuNewsroomApple:1
# LeadershipJob:1
# OpportunitiesInvestorsEventsContact:1
# AppleMore:1
# ways:1
# shop:Find:1
# Storeorother:1
# retailernear:1
# you.Or:1
# call:1
# 1-800-MY-APPLE.United:1
# StatesCopyright:1
# ©:1
# 2020:1
# Inc.:1
# All:1
# rights:1
# reserved.Privacy:1
# PolicyTerms:1
# UseSales:1
# RefundsLegalSite:1
# Map{:1
# "@context"::2
# "http://schema.org",:2
# "@id"::6
# "https://www.apple.com/#organization",:1
# "@type"::7
# "Organization",:2
# "name"::3
# "Apple",:1
# "url"::4
# "https://www.apple.com/",:1
# "logo"::1
# "https://www.apple.com/ac/structured-data/images/knowledge_graph_logo.png?202006241657",:1
# "subOrganization"::1
# "Apple:1
# Support",:1
# "https://support.apple.com",:1
# "https://support.apple.com/#organization":1
# },:6
# "contactPoint"::1
# [:2
# "ContactPoint",:3
# "telephone"::3
# "+1-800-692-7753",:1
# "contactType"::3
# "sales",:1
# "areaServed"::3
# "US":1
# "+1-800-275-2273",:2
# "technical:1
# support",:2
# "US",:2
# "availableLanguage"::2
# ["EN",:2
# "ES"]:2
# "customer:1
# ],:1
# "sameAs"::1
# "http://www.wikidata.org/entity/Q312",:1
# "https://www.youtube.com/user/Apple",:1
# "https://www.linkedin.com/company/apple",:1
# "https://www.facebook.com/Apple",:1
# "https://www.twitter.com/Apple":1
# ]:1
# }{:1
# "Product",:1
# "https://www.apple.com/iphone-11/#product",:1
# "manufacturer"::1
# "https://www.apple.com/#organization":2
# "brand"::1
# "https://www.apple.com/iphone/#brand":1
# "iPhone:1
# 11",:1
# "description"::1
# "Meet:1
# All-new:1
# dual-camera:1
# All-day:1
# Six:1
# colors.:1
# ever.",:1
# "https://www.apple.com/iphone-11/",:2
# "mainEntityOfPage"::1
# "image"::1
# "https://www.apple.com/v/iphone-11/d/images/meta/og__f2jtwncwsl2e_overview.png",:1
# "potentialAction"::1
# "BuyAction",:1
# "seller"::1
# ["https://www.apple.com/us/shop/goto/buy_iphone/iphone_11"]:1
