# %%
# Import
import os
import nltk
import nltk.corpus

# %%
# Specify Website 
import urllib.request
response = urllib.request.urlopen('https://www.apple.com/iphone-11-pro/')
html = response.read()
print(html)
# Out:
# b'\n<!DOCTYPE html>\n<html class="no-js" xmlns="http://www.w3.org/1999/xhtml" xml:lang="en-US" lang="en-US" dir="ltr" prefix="og: http://ogp.me/ns#">\n<head>\n\t\n\n\n\n\n\n    \n\n\n\n\n\n\n    \n        <script src="/metrics/target/scripts/1.0/at.js" type="text/javascript" charset="utf-8"></script>\n        <script>\n            window.AB = window.AB || {};\n            window.AB.isAbTestActive = true;\n        </script>\n    \n\n\t\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n<meta charset="utf-8" />\n<link rel="canonical" href="https://www.apple.com/iphone-11-pro/" />\n\n\n\t\n\t<link rel="alternate" href="https://www.apple.com/ae-ar/iphone-11-pro/" hreflang="ar-AE" /><link rel="alternate" href="https://www.apple.com/ae/iphone-11-pro/" hreflang="en-AE" /><link rel="alternate" href="https://www.apple.com/am/iphone-11-pro/" hreflang="en-AM" /><link rel="alternate" href="https://www.apple.com/at/iphone-11-pro/" hreflang="de-AT" /><link rel="alternate" href="https://w
# ...

# %%
# Remove all html5 elements form website using BeautifulSoup
from bs4 import BeautifulSoup
soup = BeautifulSoup(html, 'html5lib')
text = soup.get_text(strip = True)
print(text)
# Out:
# window.AB = window.AB || {};
# ...

# %%
# Convert the words into individual tokens
tokens = [t for t in text.split()]
print(tokens)
# Out:
# ['window.AB', '=', 'window.AB', '||', '{};', 'window.AB.isAbTestActive', '=', 'true;iPhone', '11', 'Pro', '-', 'AppleGlobal', 'Nav', 'Open', 'MenuGlobal', 'Nav', 'Close', 'MenuAppleShopping', 'Bag+Search', 'apple.comCancelAppleMaciPadiPhoneWatchTVMusicSupportShopping', 'Bag+CanceliPhone', '11', 'ProLocal', 'Nav', 'Open', 'MenuLocal', 'Nav', 'Close', 'MenuOverviewTech', 'SpecsBuyiPhone', '11', 'ProAnd', 'then', 'there', 'was', 'Pro.A', 'transformative', 'triple‑camera', 'system', 'that', 'adds', 'tons', 'of', 'capability', 'without', 'complexity.', 'An', 'unprecedented', 'leap', 'in', 'battery', 'life.', 'And', 'a', 'mind‑blowing', 'chip', 'that', 'doubles', 'down', 'on', 'machine', 'learning', 'and', 'pushes', 'the', 'boundaries', 'of', 'what', 'a', 'smartphone', 'can', 'do.', 'Welcome', 'to', 'the', 'first', 'iPhone', 'powerful', 'enough', 'to', 'be', 'called', 'Pro.From$29.95/mo.or$719with', 'trade‑in.*Watch', 'the', 'keynoteWatch', 'theiPhone', '11', 'profilmWatch', 'the', 'filmSe
# ...

# %%
# Removes stop words like 'a', 'at', 'the', etc
from nltk.corpus import stopwords
sr = stopwords.words('english')
clean_tokens = tokens[:]
for token in tokens:
    if token in stopwords.words('english'):
        clean_tokens.remove(token)
        
# Frequency distribution for tokens
freq = nltk.FreqDist(clean_tokens)
for key, val in freq.items():
    print(str(key) + ":" + str(val))

# Plot
freq.plot(20, cumulative = False)
# Out:
# window.AB:2
# =:2
# ||:1
# {};:1
# window.AB.isAbTestActive:1
# true;iPhone:1
# 11:37
# Pro:27
# -:1
# AppleGlobal:1
# Nav:4
# Open:2
# MenuGlobal:1
# Close:2
# MenuAppleShopping:1
# Bag+Search:1
# apple.comCancelAppleMaciPadiPhoneWatchTVMusicSupportShopping:1
# Bag+CanceliPhone:1
# ProLocal:1
# MenuLocal:1
# MenuOverviewTech:1
# SpecsBuyiPhone:1
# ProAnd:1
# Pro.A:1
# transformative:1
# triple‑camera:3
# system:5
# adds:3
# tons:1
# capability:1
# without:5
# complexity.:1
# An:1
# unprecedented:2
# leap:4
# battery:14
# life.:2
# And:12
# mind‑blowing:1
# chip:8
# doubles:1
# machine:9
# learning:7
# pushes:1
# boundaries:1
# smartphone:3
# do.:1
# Welcome:1
# first:2
# iPhone:43
# powerful:4
# enough:1
# called:1
# Pro.From$29.95/mo.or$719with:1
# trade‑in.*Watch:1
# keynoteWatch:1
# theiPhone:1
# profilmWatch:1
# filmSee:1
# ARSee:1
# ARTake:1
# closer:1
# look.Two:1
# sizes.:1
# Four:1
# finishes.:1
# Stainless:1
# steel:1
# glass:5
# design.View:1
# ...
