# %%
# setup data

import sklearn
from sklearn.utils import shuffle
from sklearn.neighbors import KNeighborsClassifier
import pandas as pd
import numpy as np
from sklearn import linear_model, preprocessing

data = pd.read_csv("car.data")
print(data.head())

# we have to convert the text strings (non numerical data) into integer values that corresponds to our string
# we use import sklearn to do this

le = preprocessing.LabelEncoder() # takes the labels and encodes them into appropriate integer values
buying = le.fit_transform(list(data["buying"]))
maint = le.fit_transform(list(data["maint"]))
door = le.fit_transform(list(data["door"]))
persons = le.fit_transform(list(data["persons"]))
lug_boot = le.fit_transform(list(data["lug_boot"]))
safety = le.fit_transform(list(data["safety"]))
cls = le.fit_transform(list(data["class"]))

print(buying) # example of how encoding works

predict = "class"

X = list(zip(buying, maint, door, persons, lug_boot, safety)) # converts all these into one big tuple list
y = list(cls)

x_train, x_test, y_train, y_test = sklearn.model_selection.train_test_split(X, y, test_size = 0.1)

print(x_train, y_test)
# Out:
#   buying  maint door persons lug_boot safety  class
# 0  vhigh  vhigh    2       2    small    low  unacc
# 1  vhigh  vhigh    2       2    small    med  unacc
# 2  vhigh  vhigh    2       2    small   high  unacc
# 3  vhigh  vhigh    2       2      med    low  unacc
# 4  vhigh  vhigh    2       2      med    med  unacc
# [3 3 3 ... 1 1 1]
# ...

# %%
# using KNN

import sklearn
from sklearn.utils import shuffle
from sklearn.neighbors import KNeighborsClassifier
import pandas as pd
import numpy as np
from sklearn import linear_model, preprocessing

data = pd.read_csv("car.data")
print(data.head())

# we have to convert the text strings (non numerical data) into integer values that corresponds to our string
# we use import sklearn to do this

le = preprocessing.LabelEncoder() # takes the labels and encodes them into appropriate integer values
buying = le.fit_transform(list(data["buying"]))
maint = le.fit_transform(list(data["maint"]))
door = le.fit_transform(list(data["door"]))
persons = le.fit_transform(list(data["persons"]))
lug_boot = le.fit_transform(list(data["lug_boot"]))
safety = le.fit_transform(list(data["safety"]))
cls = le.fit_transform(list(data["class"]))

print(buying) # example of how encoding works

predict = "class"

X = list(zip(buying, maint, door, persons, lug_boot, safety)) # converts all these into one big tuple list
y = list(cls)

x_train, x_test, y_train, y_test = sklearn.model_selection.train_test_split(X, y, test_size = 0.1)

model = KNeighborsClassifier(n_neighbors = 7)

model.fit(x_train, y_train)
acc = model.score(x_test, y_test)
print(acc) # prints the accuracy

predicted = model.predict(x_test)
names = ["unacc", "acc", "good", "vgood"]

for x in range(len(predicted) - 1):
    print("Predicted: ", names[predicted[x]-1], "| Data: ", x_test[x], "| Actual: ", names[y_test[x]-1])
    n = model.kneighbors([x_test[x]], 7, True)
    print("N: ", n)
# Out:
#   buying  maint door persons lug_boot safety   class
# 0  vhigh  vhigh    2       2    small    low   unacc
# 1  vhigh  vhigh    2       2    small    med  unacc
# 2  vhigh  vhigh    2       2    small   high   unacc
# 3  vhigh  vhigh    2       2      med    low   unacc
# 4  vhigh  vhigh    2       2      med    med   unacc
# [3 3 3 ... 1 1 1]
# 0.9595375722543352
# Predicted:  vgood | Data:  (0, 2, 3, 1, 1, 2) | Actual:  vgood
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[  97,  939,  705, 1538,  700,  416,  458]]))
# Predicted:  acc | Data:  (2, 3, 3, 1, 2, 2) | Actual:  acc
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[ 309,  134,  989,  624, 1363,  504, 1532]]))
# Predicted:  vgood | Data:  (2, 0, 2, 1, 2, 0) | Actual:  vgood
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[949, 777, 468, 643, 534, 152,  32]]))
# Predicted:  vgood | Data:  (1, 1, 2, 2, 1, 0) | Actual:  vgood
# ...
